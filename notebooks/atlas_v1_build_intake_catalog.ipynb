# %% [markdown]
# # Build intake catalog for ATLAS v1 datasets

# %%
import pandas as pd
import numpy as np

# %%
## load manifest

df = pd.read_csv("../atlas_v1/manifest_cica_20231214.txt", names=["url"])
df
# Out:
#                                                    url
# 0    https://data.mips.copernicus-climate.eu/thredd...
# 1    https://data.mips.copernicus-climate.eu/thredd...
# 2    https://data.mips.copernicus-climate.eu/thredd...
# 3    https://data.mips.copernicus-climate.eu/thredd...
# 4    https://data.mips.copernicus-climate.eu/thredd...
# ..                                                 ...
# 407  https://data.mips.copernicus-climate.eu/thredd...
# 408  https://data.mips.copernicus-climate.eu/thredd...
# 409  https://data.mips.copernicus-climate.eu/thredd...
# 410  https://data.mips.copernicus-climate.eu/thredd...
# 411  https://data.mips.copernicus-climate.eu/thredd...
#
# [412 rows x 1 columns]

# %%
df.url[0]
# Out:
# 'https://data.mips.copernicus-climate.eu/thredds/fileServer/esg_c3s-ipcc-atlas/CMIP5/historical/pr_CMIP5_historical_mon_185001-200512.nc'

# %%
## build new dataframe

df_new = pd.DataFrame(columns = [
    'ds_id', 
    'path',
    'size',
    'project',
    'domain',
    'experiment',
    'time_frequency',
    'variable',
    'start_time',
    'end_time',
    'bbox',
    'level',
    'url',
])
df_new
# Out:
# Empty DataFrame
# Columns: [ds_id, path, size, project, domain, experiment, time_frequency, variable, start_time, end_time, bbox, level, url]
# Index: []

# %%
df_new["url"] = df["url"].str.replace("/esg_c3s-ipcc-atlas/", "/esg_c3s-cica-atlas/", regex=False)
df_new.head()
# Out:
#   ds_id path size project domain experiment time_frequency variable  \
# 0   NaN  NaN  NaN     NaN    NaN        NaN            NaN      NaN
# 1   NaN  NaN  NaN     NaN    NaN        NaN            NaN      NaN
# 2   NaN  NaN  NaN     NaN    NaN        NaN            NaN      NaN
# 3   NaN  NaN  NaN     NaN    NaN        NaN            NaN      NaN
# 4   NaN  NaN  NaN     NaN    NaN        NaN            NaN      NaN
#
#   start_time end_time bbox level  \
# 0        NaN      NaN  NaN   NaN
# 1        NaN      NaN  NaN   NaN
# 2        NaN      NaN  NaN   NaN
# 3        NaN      NaN  NaN   NaN
# 4        NaN      NaN  NaN   NaN
#
#                                                  url
# 0  https://data.mips.copernicus-climate.eu/thredd...
# 1  https://data.mips.copernicus-climate.eu/thredd...
# 2  https://data.mips.copernicus-climate.eu/thredd...
# 3  https://data.mips.copernicus-climate.eu/thredd...
# 4  https://data.mips.copernicus-climate.eu/thredd...

# %%
df_new["path"] = df_new["url"].str.replace("https://data.mips.copernicus-climate.eu/thredds/fileServer/esg_c3s-cica-atlas/", "", regex=False)
df_new.head()
# Out:
#   ds_id                                               path size project  \
# 0   NaN  CMIP5/historical/pr_CMIP5_historical_mon_18500...  NaN     NaN
# 1   NaN  CMIP5/historical/prsn_CMIP5_historical_mon_185...  NaN     NaN
# 2   NaN  CMIP5/historical/rx1day_CMIP5_historical_mon_1...  NaN     NaN
# 3   NaN  CMIP5/historical/rx5day_CMIP5_historical_mon_1...  NaN     NaN
# 4   NaN  CMIP5/historical/sfcwind_CMIP5_historical_mon_...  NaN     NaN
#
#   domain experiment time_frequency variable start_time end_time bbox level  \
# 0    NaN        NaN            NaN      NaN        NaN      NaN  NaN   NaN
# 1    NaN        NaN            NaN      NaN        NaN      NaN  NaN   NaN
# 2    NaN        NaN            NaN      NaN        NaN      NaN  NaN   NaN
# 3    NaN        NaN            NaN      NaN        NaN      NaN  NaN   NaN
# 4    NaN        NaN            NaN      NaN        NaN      NaN  NaN   NaN
#
#                                                  url
# 0  https://data.mips.copernicus-climate.eu/thredd...
# 1  https://data.mips.copernicus-climate.eu/thredd...
# 2  https://data.mips.copernicus-climate.eu/thredd...
# 3  https://data.mips.copernicus-climate.eu/thredd...
# 4  https://data.mips.copernicus-climate.eu/thredd...

# %%
df_new["ds_id"] = df_new["path"].apply(lambda x: 'c3s-cica-atlas.' + '.'.join(x.split('/')[-1].split('_')[0:-1]))
df_new.head()
# Out:
#                                          ds_id  \
# 0       c3s-cica-atlas.pr.CMIP5.historical.mon
# 1     c3s-cica-atlas.prsn.CMIP5.historical.mon
# 2   c3s-cica-atlas.rx1day.CMIP5.historical.mon
# 3   c3s-cica-atlas.rx5day.CMIP5.historical.mon
# 4  c3s-cica-atlas.sfcwind.CMIP5.historical.mon
#
#                                                 path size project domain  \
# 0  CMIP5/historical/pr_CMIP5_historical_mon_18500...  NaN     NaN    NaN
# 1  CMIP5/historical/prsn_CMIP5_historical_mon_185...  NaN     NaN    NaN
# 2  CMIP5/historical/rx1day_CMIP5_historical_mon_1...  NaN     NaN    NaN
# 3  CMIP5/historical/rx5day_CMIP5_historical_mon_1...  NaN     NaN    NaN
# 4  CMIP5/historical/sfcwind_CMIP5_historical_mon_...  NaN     NaN    NaN
#
#   experiment time_frequency variable start_time end_time bbox level  \
# 0        NaN            NaN      NaN        NaN      NaN  NaN   NaN
# 1        NaN            NaN      NaN        NaN      NaN  NaN   NaN
# 2        NaN            NaN      NaN        NaN      NaN  NaN   NaN
# 3        NaN            NaN      NaN        NaN      NaN  NaN   NaN
# 4        NaN            NaN      NaN        NaN      NaN  NaN   NaN
#
#                                                  url
# 0  https://data.mips.copernicus-climate.eu/thredd...
# 1  https://data.mips.copernicus-climate.eu/thredd...
# 2  https://data.mips.copernicus-climate.eu/thredd...
# 3  https://data.mips.copernicus-climate.eu/thredd...
# 4  https://data.mips.copernicus-climate.eu/thredd...

# %%
df_new.ds_id[0]
# Out:
# 'c3s-cica-atlas.pr.CMIP5.historical.mon'

# %%
# Let’s agree on “Europe” for E-OBS, “Europe (EURO-CORDEX)” for CORDEX-EUR-11 and “Global (mosaic)” for CODEX-CORE (the others are all “Global”).

def get_project(ds_id):
    project = ds_id.split(".")[2]
    # project = project.split("-")[0]
    return project

def get_domain(ds_id):
    project = ds_id.split(".")[2]
    if project == "E-OBS":
        domain = "Europe"
    elif project == "CORDEX-EUR-11":
        domain = "Europe (EURO-CORDEX)"
    elif project == "CORDEX-CORE":
        domain = "Global (mosaic)"
    else:
        domain = "Global"
    return domain

def get_experiment(ds_id):
    parts = ds_id.split('.')
    if len(parts) == 5:
        exp = parts[3]
    else:
        exp = np.nan
    return exp
    

def get_start_time(path):
    parts = path.split("_")
    part = parts[-1]
    start = part.split("-")[0]
    if "mon" in parts:
        start_time = f"{start[0:4]}-{start[4:6]}-01T00:00:00"
    else:
        start_time = f"{start[0:4]}-01-01T00:00:00"
    return start_time


def get_end_time(path):
    parts = path.split("_")
    part = parts[-1]
    end = part.split("-")[1]
    if "mon" in parts:
        end_time = f"{end[0:4]}-{end[4:6]}-31T00:00:00"
    else:
        end_time = f"{end[0:4]}-12-31T00:00:00"
    return end_time

# %%
df_new['project'] = df_new["ds_id"].apply(get_project)
df_new['domain'] = df_new["ds_id"].apply(get_domain)
df_new['experiment'] = df_new["ds_id"].apply(get_experiment)
df_new['time_frequency'] = df_new["ds_id"].apply(lambda x: x.split('.')[-1])
df_new['variable'] = df_new["ds_id"].apply(lambda x: x.split('.')[1])
df_new['start_time'] = df_new["path"].apply(get_start_time)
df_new['end_time'] = df_new["path"].apply(get_end_time)
df_new
# Out:
#                                            ds_id  \
# 0         c3s-cica-atlas.pr.CMIP5.historical.mon
# 1       c3s-cica-atlas.prsn.CMIP5.historical.mon
# 2     c3s-cica-atlas.rx1day.CMIP5.historical.mon
# 3     c3s-cica-atlas.rx5day.CMIP5.historical.mon
# 4    c3s-cica-atlas.sfcwind.CMIP5.historical.mon
# ..                                           ...
# 407                 c3s-cica-atlas.tx40.ERA5.mon
# 408                  c3s-cica-atlas.txx.ERA5.mon
# 409                   c3s-cica-atlas.tx.ERA5.mon
# 410              c3s-cica-atlas.siconc.ORAS5.mon
# 411                 c3s-cica-atlas.sst.ORAS5.mon
#
#                                                   path size project  domain  \
# 0    CMIP5/historical/pr_CMIP5_historical_mon_18500...  NaN   CMIP5  Global
# 1    CMIP5/historical/prsn_CMIP5_historical_mon_185...  NaN   CMIP5  Global
# 2    CMIP5/historical/rx1day_CMIP5_historical_mon_1...  NaN   CMIP5  Global
# 3    CMIP5/historical/rx5day_CMIP5_historical_mon_1...  NaN   CMIP5  Global
# 4    CMIP5/historical/sfcwind_CMIP5_historical_mon_...  NaN   CMIP5  Global
# ..                                                 ...  ...     ...     ...
# 407                ERA5/tx40_ERA5_mon_194001-202212.nc  NaN    ERA5  Global
# 408                 ERA5/txx_ERA5_mon_194001-202212.nc  NaN    ERA5  Global
# 409                  ERA5/tx_ERA5_mon_194001-202212.nc  NaN    ERA5  Global
# 410            ORAS5/siconc_ORAS5_mon_195801-201412.nc  NaN   ORAS5  Global
# 411               ORAS5/sst_ORAS5_mon_195801-201412.nc  NaN   ORAS5  Global
#
#      experiment time_frequency variable           start_time  \
# 0    historical            mon       pr  1850-01-01T00:00:00
# 1    historical            mon     prsn  1850-01-01T00:00:00
# 2    historical            mon   rx1day  1850-01-01T00:00:00
# 3    historical            mon   rx5day  1850-01-01T00:00:00
# 4    historical            mon  sfcwind  1850-01-01T00:00:00
# ..          ...            ...      ...                  ...
# 407         NaN            mon     tx40  1940-01-01T00:00:00
# 408         NaN            mon      txx  1940-01-01T00:00:00
# 409         NaN            mon       tx  1940-01-01T00:00:00
# 410         NaN            mon   siconc  1958-01-01T00:00:00
# 411         NaN            mon      sst  1958-01-01T00:00:00
#
#                 end_time bbox level  \
# 0    2005-12-31T00:00:00  NaN   NaN
# 1    2005-12-31T00:00:00  NaN   NaN
# 2    2005-12-31T00:00:00  NaN   NaN
# 3    2005-12-31T00:00:00  NaN   NaN
# 4    2005-12-31T00:00:00  NaN   NaN
# ..                   ...  ...   ...
# 407  2022-12-31T00:00:00  NaN   NaN
# 408  2022-12-31T00:00:00  NaN   NaN
# 409  2022-12-31T00:00:00  NaN   NaN
# 410  2014-12-31T00:00:00  NaN   NaN
# 411  2014-12-31T00:00:00  NaN   NaN
#
#                                                    url
# 0    https://data.mips.copernicus-climate.eu/thredd...
# 1    https://data.mips.copernicus-climate.eu/thredd...
# 2    https://data.mips.copernicus-climate.eu/thredd...
# 3    https://data.mips.copernicus-climate.eu/thredd...
# 4    https://data.mips.copernicus-climate.eu/thredd...
# ..                                                 ...
# 407  https://data.mips.copernicus-climate.eu/thredd...
# 408  https://data.mips.copernicus-climate.eu/thredd...
# 409  https://data.mips.copernicus-climate.eu/thredd...
# 410  https://data.mips.copernicus-climate.eu/thredd...
# 411  https://data.mips.copernicus-climate.eu/thredd...
#
# [412 rows x 13 columns]

# %% [markdown]
# ## show values

# %%
df_new.nunique()
# Out:
# ds_id             412
# path              412
# size                0
# project             8
# domain              4
# experiment          8
# time_frequency      2
# variable           30
# start_time          7
# end_time            5
# bbox                0
# level               0
# url               412
# dtype: int64

# %%
list(df_new.project.unique())
# Out:
# ['CMIP5',
#  'CMIP6',
#  'CORDEX-CORE',
#  'CORDEX-EUR-11',
#  'E-OBS',
#  'ERA5',
#  'ERA5-Land',
#  'ORAS5']

# %%
list(df_new.domain.unique())
# Out:
# ['Global', 'Global (mosaic)', 'Europe (EURO-CORDEX)', 'Europe']

# %%
list(df_new.experiment.unique())
# Out:
# ['historical',
#  'rcp26',
#  'rcp45',
#  'rcp85',
#  'ssp126',
#  'ssp245',
#  'ssp370',
#  'ssp585',
#  nan]

# %%
list(df_new.time_frequency.unique())
# Out:
# ['mon', 'yr']

# %%
list(df_new.variable.unique())
# Out:
# ['pr',
#  'prsn',
#  'rx1day',
#  'rx5day',
#  'sfcwind',
#  't',
#  'tn',
#  'tnn',
#  'tx35',
#  'tx',
#  'tx40',
#  'txx',
#  'cd',
#  'cdd',
#  'clt',
#  'evspsbl',
#  'fd',
#  'hd',
#  'huss',
#  'mrro',
#  'mrsos',
#  'psl',
#  'rlds',
#  'rsds',
#  'siconc',
#  'spei6',
#  'spi6',
#  'sst',
#  'tx35bals',
#  'tx40bals']

# %%
list(df_new.start_time.unique())
# Out:
# ['1850-01-01T00:00:00',
#  '2006-01-01T00:00:00',
#  '2015-01-01T00:00:00',
#  '1970-01-01T00:00:00',
#  '1950-01-01T00:00:00',
#  '1940-01-01T00:00:00',
#  '1958-01-01T00:00:00']

# %%
list(df_new.end_time.unique())
# Out:
# ['2005-12-31T00:00:00',
#  '2100-12-31T00:00:00',
#  '2014-12-31T00:00:00',
#  '2021-12-31T00:00:00',
#  '2022-12-31T00:00:00']

# %% [markdown]
# ## Write new catalog

# %%
from datetime import datetime

last_updated = datetime.now().utcnow()
version = last_updated.strftime('v%Y%m%d')
cat_name = f"c3s-cica-atlas_{version}.csv.gz"
cat_path = f"../intake/catalogs/c3s-atlas/{cat_name}"

df_new.to_csv(cat_path, index=False, compression="gzip")
