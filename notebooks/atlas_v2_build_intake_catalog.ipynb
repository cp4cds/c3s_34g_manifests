# %% [markdown]
# # Build intake catalog for ATLAS v2 datasets

# %%
import pandas as pd
import numpy as np

# %%
## load manifest

df = pd.read_csv("../atlas_v2/manifest-atlas-v2_20250317.txt", names=["url"])
df
# Out:
#                                                     url
# 0     https://data.mips.copernicus-climate.eu/thredd...
# 1     https://data.mips.copernicus-climate.eu/thredd...
# 2     https://data.mips.copernicus-climate.eu/thredd...
# 3     https://data.mips.copernicus-climate.eu/thredd...
# 4     https://data.mips.copernicus-climate.eu/thredd...
# ...                                                 ...
# 1013  https://data.mips.copernicus-climate.eu/thredd...
# 1014  https://data.mips.copernicus-climate.eu/thredd...
# 1015  https://data.mips.copernicus-climate.eu/thredd...
# 1016  https://data.mips.copernicus-climate.eu/thredd...
# 1017  https://data.mips.copernicus-climate.eu/thredd...
#
# [1018 rows x 1 columns]

# %%
df.url[0]
# Out:
# 'https://data.mips.copernicus-climate.eu/thredds/fileServer/esg_c3s-cica-atlas/v02/CMIP6/historical/tr_CMIP6_historical_mon_185001-201412.nc'

# %%
## build new dataframe

df_new = pd.DataFrame(columns = [
    'ds_id',
    'version',
    'path',
    'size',
    'project',
    'domain',
    'experiment',
    'time_frequency',
    'variable',
    'start_time',
    'end_time',
    'bbox',
    'level',
    'url',
])
df_new
# Out:
# Empty DataFrame
# Columns: [ds_id, version, path, size, project, domain, experiment, time_frequency, variable, start_time, end_time, bbox, level, url]
# Index: []

# %%
df_new["url"] = df["url"].str.replace("/esg_c3s-cica-atlas/v02", "/esg_c3s-cica-atlas/v02", regex=False)
df_new.head()
# Out:
#   ds_id version path size project domain experiment time_frequency variable  \
# 0   NaN     NaN  NaN  NaN     NaN    NaN        NaN            NaN      NaN
# 1   NaN     NaN  NaN  NaN     NaN    NaN        NaN            NaN      NaN
# 2   NaN     NaN  NaN  NaN     NaN    NaN        NaN            NaN      NaN
# 3   NaN     NaN  NaN  NaN     NaN    NaN        NaN            NaN      NaN
# 4   NaN     NaN  NaN  NaN     NaN    NaN        NaN            NaN      NaN
#
#   start_time end_time bbox level  \
# 0        NaN      NaN  NaN   NaN
# 1        NaN      NaN  NaN   NaN
# 2        NaN      NaN  NaN   NaN
# 3        NaN      NaN  NaN   NaN
# 4        NaN      NaN  NaN   NaN
#
#                                                  url
# 0  https://data.mips.copernicus-climate.eu/thredd...
# 1  https://data.mips.copernicus-climate.eu/thredd...
# 2  https://data.mips.copernicus-climate.eu/thredd...
# 3  https://data.mips.copernicus-climate.eu/thredd...
# 4  https://data.mips.copernicus-climate.eu/thredd...

# %%
df_new["path"] = df_new["url"].str.replace("https://data.mips.copernicus-climate.eu/thredds/fileServer/esg_c3s-cica-atlas/v02/", "", regex=False)
df_new.head()
# Out:
#   ds_id version                                               path size  \
# 0   NaN     NaN  CMIP6/historical/tr_CMIP6_historical_mon_18500...  NaN
# 1   NaN     NaN  CMIP6/historical/r01_CMIP6_historical_mon_1850...  NaN
# 2   NaN     NaN  CMIP6/historical/fdbals_CMIP6_historical_mon_1...  NaN
# 3   NaN     NaN  CMIP6/historical/sst_CMIP6_historical_mon_1850...  NaN
# 4   NaN     NaN  CMIP6/historical/spei6_CMIP6_historical_mon_18...  NaN
#
#   project domain experiment time_frequency variable start_time end_time bbox  \
# 0     NaN    NaN        NaN            NaN      NaN        NaN      NaN  NaN
# 1     NaN    NaN        NaN            NaN      NaN        NaN      NaN  NaN
# 2     NaN    NaN        NaN            NaN      NaN        NaN      NaN  NaN
# 3     NaN    NaN        NaN            NaN      NaN        NaN      NaN  NaN
# 4     NaN    NaN        NaN            NaN      NaN        NaN      NaN  NaN
#
#   level                                                url
# 0   NaN  https://data.mips.copernicus-climate.eu/thredd...
# 1   NaN  https://data.mips.copernicus-climate.eu/thredd...
# 2   NaN  https://data.mips.copernicus-climate.eu/thredd...
# 3   NaN  https://data.mips.copernicus-climate.eu/thredd...
# 4   NaN  https://data.mips.copernicus-climate.eu/thredd...

# %%
version = "v2"

df_new["ds_id"] = df_new["path"].apply(lambda x: 'c3s-cica-atlas.' + '.'.join(x.split('/')[-1].split('_')[0:-1]) + '.' + version)
df_new.head()
# Out:
#                                            ds_id version  \
# 0      c3s-cica-atlas.tr.CMIP6.historical.mon.v2     NaN
# 1     c3s-cica-atlas.r01.CMIP6.historical.mon.v2     NaN
# 2  c3s-cica-atlas.fdbals.CMIP6.historical.mon.v2     NaN
# 3     c3s-cica-atlas.sst.CMIP6.historical.mon.v2     NaN
# 4   c3s-cica-atlas.spei6.CMIP6.historical.mon.v2     NaN
#
#                                                 path size project domain  \
# 0  CMIP6/historical/tr_CMIP6_historical_mon_18500...  NaN     NaN    NaN
# 1  CMIP6/historical/r01_CMIP6_historical_mon_1850...  NaN     NaN    NaN
# 2  CMIP6/historical/fdbals_CMIP6_historical_mon_1...  NaN     NaN    NaN
# 3  CMIP6/historical/sst_CMIP6_historical_mon_1850...  NaN     NaN    NaN
# 4  CMIP6/historical/spei6_CMIP6_historical_mon_18...  NaN     NaN    NaN
#
#   experiment time_frequency variable start_time end_time bbox level  \
# 0        NaN            NaN      NaN        NaN      NaN  NaN   NaN
# 1        NaN            NaN      NaN        NaN      NaN  NaN   NaN
# 2        NaN            NaN      NaN        NaN      NaN  NaN   NaN
# 3        NaN            NaN      NaN        NaN      NaN  NaN   NaN
# 4        NaN            NaN      NaN        NaN      NaN  NaN   NaN
#
#                                                  url
# 0  https://data.mips.copernicus-climate.eu/thredd...
# 1  https://data.mips.copernicus-climate.eu/thredd...
# 2  https://data.mips.copernicus-climate.eu/thredd...
# 3  https://data.mips.copernicus-climate.eu/thredd...
# 4  https://data.mips.copernicus-climate.eu/thredd...

# %%
df_new.ds_id[0]
# Out:
# 'c3s-cica-atlas.tr.CMIP6.historical.mon.v2'

# %%
# Let’s agree on “Europe” for E-OBS, “Europe (EURO-CORDEX)” for CORDEX-EUR-11 and “Global (mosaic)” for CODEX-CORE (the others are all “Global”).

def get_project(ds_id):
    project = ds_id.split(".")[2]
    # project = project.split("-")[0]
    return project

def get_domain(ds_id):
    project = ds_id.split(".")[2]
    if project == "E-OBS":
        domain = "Europe"
    elif project == "CORDEX-EUR-11":
        domain = "Europe (EURO-CORDEX)"
    elif project == "CORDEX-CORE":
        domain = "Global (mosaic)"
    else:
        domain = "Global"
    return domain

def get_experiment(ds_id):
    parts = ds_id.split('.')
    if len(parts) == 6:
        exp = parts[3]
    else:
        exp = np.nan
    return exp
    

def get_start_time(path):
    parts = path.split("_")
    part = parts[-1]
    start = part.split("-")[0]
    if "mon" in parts:
        start_time = f"{start[0:4]}-{start[4:6]}-01T00:00:00"
    else:
        start_time = f"{start[0:4]}-01-01T00:00:00"
    return start_time


def get_end_time(path):
    parts = path.split("_")
    part = parts[-1]
    end = part.split("-")[1]
    if "mon" in parts:
        end_time = f"{end[0:4]}-{end[4:6]}-31T00:00:00"
    else:
        end_time = f"{end[0:4]}-12-31T00:00:00"
    return end_time

def get_version(ds_id):
    return "v1"

# %%
df_new['version'] = df_new['ds_id'].apply(get_version)
df_new['project'] = df_new["ds_id"].apply(get_project)
df_new['domain'] = df_new["ds_id"].apply(get_domain)
df_new['experiment'] = df_new["ds_id"].apply(get_experiment)
df_new['time_frequency'] = df_new["ds_id"].apply(lambda x: x.split('.')[-2])
df_new['variable'] = df_new["ds_id"].apply(lambda x: x.split('.')[1])
df_new['start_time'] = df_new["path"].apply(get_start_time)
df_new['end_time'] = df_new["path"].apply(get_end_time)
df_new
# Out:
#                                               ds_id version  \
# 0         c3s-cica-atlas.tr.CMIP6.historical.mon.v2      v1
# 1        c3s-cica-atlas.r01.CMIP6.historical.mon.v2      v1
# 2     c3s-cica-atlas.fdbals.CMIP6.historical.mon.v2      v1
# 3        c3s-cica-atlas.sst.CMIP6.historical.mon.v2      v1
# 4      c3s-cica-atlas.spei6.CMIP6.historical.mon.v2      v1
# ...                                             ...     ...
# 1013             c3s-cica-atlas.tnn.BERKELEY.mon.v2      v1
# 1014               c3s-cica-atlas.t.BERKELEY.mon.v2      v1
# 1015            c3s-cica-atlas.tx35.BERKELEY.mon.v2      v1
# 1016             c3s-cica-atlas.dtr.BERKELEY.mon.v2      v1
# 1017            c3s-cica-atlas.tx40.BERKELEY.mon.v2      v1
#
#                                                    path size   project  \
# 0     CMIP6/historical/tr_CMIP6_historical_mon_18500...  NaN     CMIP6
# 1     CMIP6/historical/r01_CMIP6_historical_mon_1850...  NaN     CMIP6
# 2     CMIP6/historical/fdbals_CMIP6_historical_mon_1...  NaN     CMIP6
# 3     CMIP6/historical/sst_CMIP6_historical_mon_1850...  NaN     CMIP6
# 4     CMIP6/historical/spei6_CMIP6_historical_mon_18...  NaN     CMIP6
# ...                                                 ...  ...       ...
# 1013         BERKELEY/tnn_BERKELEY_mon_188101-201712.nc  NaN  BERKELEY
# 1014           BERKELEY/t_BERKELEY_mon_188101-201712.nc  NaN  BERKELEY
# 1015        BERKELEY/tx35_BERKELEY_mon_188101-201712.nc  NaN  BERKELEY
# 1016         BERKELEY/dtr_BERKELEY_mon_188101-201712.nc  NaN  BERKELEY
# 1017        BERKELEY/tx40_BERKELEY_mon_188101-201712.nc  NaN  BERKELEY
#
#       domain  experiment time_frequency variable           start_time  \
# 0     Global  historical            mon       tr  1850-01-01T00:00:00
# 1     Global  historical            mon      r01  1850-01-01T00:00:00
# 2     Global  historical            mon   fdbals  1850-01-01T00:00:00
# 3     Global  historical            mon      sst  1850-01-01T00:00:00
# 4     Global  historical            mon    spei6  1850-01-01T00:00:00
# ...      ...         ...            ...      ...                  ...
# 1013  Global         NaN            mon      tnn  1881-01-01T00:00:00
# 1014  Global         NaN            mon        t  1881-01-01T00:00:00
# 1015  Global         NaN            mon     tx35  1881-01-01T00:00:00
# 1016  Global         NaN            mon      dtr  1881-01-01T00:00:00
# 1017  Global         NaN            mon     tx40  1881-01-01T00:00:00
#
#                  end_time bbox level  \
# 0     2014-12-31T00:00:00  NaN   NaN
# 1     2014-12-31T00:00:00  NaN   NaN
# 2     2014-12-31T00:00:00  NaN   NaN
# 3     2014-12-31T00:00:00  NaN   NaN
# 4     2014-12-31T00:00:00  NaN   NaN
# ...                   ...  ...   ...
# 1013  2017-12-31T00:00:00  NaN   NaN
# 1014  2017-12-31T00:00:00  NaN   NaN
# 1015  2017-12-31T00:00:00  NaN   NaN
# 1016  2017-12-31T00:00:00  NaN   NaN
# 1017  2017-12-31T00:00:00  NaN   NaN
#
#                                                     url
# 0     https://data.mips.copernicus-climate.eu/thredd...
# 1     https://data.mips.copernicus-climate.eu/thredd...
# 2     https://data.mips.copernicus-climate.eu/thredd...
# 3     https://data.mips.copernicus-climate.eu/thredd...
# 4     https://data.mips.copernicus-climate.eu/thredd...
# ...                                                 ...
# 1013  https://data.mips.copernicus-climate.eu/thredd...
# 1014  https://data.mips.copernicus-climate.eu/thredd...
# 1015  https://data.mips.copernicus-climate.eu/thredd...
# 1016  https://data.mips.copernicus-climate.eu/thredd...
# 1017  https://data.mips.copernicus-climate.eu/thredd...
#
# [1018 rows x 14 columns]

# %% [markdown]
# ## show values

# %%
df_new.nunique()
# Out:
# ds_id             1018
# version              1
# path              1018
# size                 0
# project              9
# domain               4
# experiment           9
# time_frequency       2
# variable            56
# start_time           8
# end_time             7
# bbox                 0
# level                0
# url               1018
# dtype: int64

# %%
list(df_new.version.unique())
# Out:
# ['v1']

# %%
list(df_new.project.unique())
# Out:
# ['CMIP6',
#  'E-OBS',
#  'CMIP5',
#  'CERRA',
#  'ERA5-Land',
#  'CORDEX-CORE',
#  'CORDEX-EUR-11',
#  'CPC',
#  'BERKELEY']

# %%
list(df_new.domain.unique())
# Out:
# ['Global', 'Europe', 'Global (mosaic)', 'Europe (EURO-CORDEX)']

# %%
list(df_new.experiment.unique())
# Out:
# ['historical',
#  'ssp126',
#  'ssp119',
#  'ssp245',
#  'ssp585',
#  'ssp370',
#  nan,
#  'rcp45',
#  'rcp85',
#  'rcp26']

# %%
list(df_new.time_frequency.unique())
# Out:
# ['mon', 'yr']

# %%
list(df_new.variable.unique())
# Out:
# ['tr',
#  'r01',
#  'fdbals',
#  'sst',
#  'spei6',
#  'rlds',
#  'spi6',
#  'rsds',
#  'sdiibaisimip',
#  'cddbaisimip',
#  'sdii',
#  'trbals',
#  'dtr',
#  'fd',
#  'rx1day',
#  'tx35',
#  'clt',
#  'tx35baisimip',
#  'tx40bals',
#  'dtrbals',
#  't',
#  'tx35bals',
#  'cdd',
#  'siconc',
#  'psl',
#  'tx40baisimip',
#  'tx',
#  'fdbaisimip',
#  'mrsos',
#  'prsn',
#  'tn',
#  'tx40',
#  'huss',
#  'r20baisimip',
#  'hdbaisimip',
#  'r10',
#  'txx',
#  'dtrbaisimip',
#  'evspsbl',
#  'trbaisimip',
#  'sfcwind',
#  'hdbals',
#  'r01baisimip',
#  'rx5day',
#  'pet',
#  'mrro',
#  'r',
#  'cdbaisimip',
#  'tnn',
#  'r10baisimip',
#  'hd',
#  'r20',
#  'cdbals',
#  'cd',
#  'spei6fullperiod',
#  'spi6fullperiod']

# %%
list(df_new.start_time.unique())
# Out:
# ['1850-01-01T00:00:00',
#  '2015-01-01T00:00:00',
#  '1950-01-01T00:00:00',
#  '2006-01-01T00:00:00',
#  '1985-01-01T00:00:00',
#  '1970-01-01T00:00:00',
#  '1979-01-01T00:00:00',
#  '1881-01-01T00:00:00']

# %%
list(df_new.end_time.unique())
# Out:
# ['2014-12-31T00:00:00',
#  '2100-12-31T00:00:00',
#  '2021-12-31T00:00:00',
#  '2005-12-31T00:00:00',
#  '2023-12-31T00:00:00',
#  '2020-12-31T00:00:00',
#  '2017-12-31T00:00:00']

# %% [markdown]
# ## Write new catalog

# %%
from datetime import datetime

last_updated = datetime.now().utcnow()
version = last_updated.strftime('v%Y%m%d')
cat_name = f"c3s-cica-atlas_v02_{version}.csv.gz"
cat_path = f"../intake/catalogs/c3s-atlas/{cat_name}"

df_new.to_csv(cat_path, index=False, compression="gzip")
# Out:
# /var/folders/5f/t661zdnd181ck1dv429s4p8r0000gn/T/ipykernel_14349/421035476.py:3: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   last_updated = datetime.now().utcnow()
