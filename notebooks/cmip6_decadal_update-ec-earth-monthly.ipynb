# %% [markdown]
# # CMIP6 Decadal catalog: update EC-EARTH
#
# Filter out the daily minimum/maximum near surface temperature from the monthly datasets, please? This is available only for the EC-EARTH model.

# %%
import intake
import pandas as pd

# %%
#cat_url = "https://raw.githubusercontent.com/cp4cds/c3s_34g_manifests/master/intake/catalogs/c3s.yaml"
cat_url = "https://raw.githubusercontent.com/cp4cds/c3s_34g_manifests/update-cmip6-decdal/intake/catalogs/c3s.yaml"

cat = intake.open_catalog(cat_url)
list(cat)
# Out:
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# File ~/miniconda3/envs/c3s-catalogs/lib/python3.12/site-packages/fsspec/implementations/http.py:414, in HTTPFileSystem._info(self, url, **kwargs)
#     412 try:
#     413     info.update(
# --> 414         await _file_info(
#     415             self.encode_url(url),
#     416             size_policy=policy,
#     417             session=session,
#     418             **self.kwargs,
#     419             **kwargs,
#     420         )
#     421     )
#     422     if info.get("size") is not None:
#
# File ~/miniconda3/envs/c3s-catalogs/lib/python3.12/site-packages/fsspec/implementations/http.py:849, in _file_info(url, session, size_policy, **kwargs)
#     848 async with r:
# --> 849     r.raise_for_status()
#     851     # TODO:
#     852     #  recognise lack of 'Accept-Ranges',
# ...

# %% [markdown]
# ## Load combined cmip6 decadal catalog

# %%
df_cmip6_decadal = cat['c3s-cmip6-decadal'].read()
df_cmip6_decadal
# Out:
#                                                     ds_id  \
# 0       c3s-cmip6-decadal.DCPP.MPI-M.MPI-ESM1-2-HR.dcp...
# 1       c3s-cmip6-decadal.DCPP.MPI-M.MPI-ESM1-2-HR.dcp...
# 2       c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
# 3       c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
# 4       c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
# ...                                                   ...
# 128680  c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
# 128681  c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
# 128682  c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
# 128683  c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
# 128684  c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
#
#                                                      path       size  \
# 0       DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2016-...  492479692
# 1       DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2009-...  737204109
# ...

# %%
df_cmip6_decadal.nunique()
# Out:
# ds_id               21325
# path               128685
# size               118251
# mip_era                 1
# activity_id             1
# institution_id          5
# source_id               5
# experiment_id           2
# member_id            1602
# table_id                3
# variable_id             6
# grid_label              2
# version                38
# start_time            469
# end_time              651
# bbox                    6
# level                   3
# member_year            62
# member_ensemble        26
# prefix                  1
# dtype: int64

# %%
df_cmip6_decadal.institution_id.unique()
# Out:
# array(['MPI-M', 'MOHC', 'CMCC', 'DWD', 'EC-Earth-Consortium'],
#       dtype=object)

# %%
df = df_cmip6_decadal.loc[df_cmip6_decadal.institution_id == 'MPI-M']
df.nunique()
# Out:
# ds_id              4165
# path               4165
# size               4140
# mip_era               1
# activity_id           1
# institution_id        1
# source_id             1
# experiment_id         1
# member_id           595
# table_id              3
# variable_id           6
# grid_label            1
# version              31
# start_time          120
# end_time            120
# bbox                  1
# level                 2
# member_year          60
# member_ensemble      10
# prefix                1
# dtype: int64

# %% [markdown]
# ## drop some mpi-m datasets
#
# ```
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r10i1p1f1/day/tasmin/gn/v20210130/tasmin_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r10i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r10i1p1f1/day/pr/gn/v20210128/pr_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r10i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r10i1p1f1/day/tasmax/gn/v20210130/tasmax_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r10i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r10i1p1f1/AERday/zg500/gn/v20210128/zg500_AERday_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r10i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r10i1p1f1/Amon/tas/gn/v20200909/tas_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r10i1p1f1_gn_201911-202912.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r10i1p1f1/Amon/psl/gn/v20200909/psl_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r10i1p1f1_gn_201911-202912.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r10i1p1f1/Amon/pr/gn/v20210122/pr_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r10i1p1f1_gn_201911-202912.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r9i1p1f1/day/tasmin/gn/v20210121/tasmin_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r9i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r9i1p1f1/day/pr/gn/v20210119/pr_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r9i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r9i1p1f1/day/tasmax/gn/v20210121/tasmax_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r9i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r9i1p1f1/AERday/zg500/gn/v20210119/zg500_AERday_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r9i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r9i1p1f1/Amon/tas/gn/v20200909/tas_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r9i1p1f1_gn_201911-202912.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r9i1p1f1/Amon/psl/gn/v20200909/psl_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r9i1p1f1_gn_201911-202912.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r9i1p1f1/Amon/pr/gn/v20210121/pr_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r9i1p1f1_gn_201911-202912.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r6i1p1f1/day/tasmin/gn/v20201207/tasmin_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r6i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r6i1p1f1/day/pr/gn/v20201217/pr_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r6i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r6i1p1f1/day/tasmax/gn/v20201207/tasmax_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r6i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r6i1p1f1/AERday/zg500/gn/v20201213/zg500_AERday_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r6i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r6i1p1f1/Amon/tas/gn/v20200909/tas_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r6i1p1f1_gn_201911-202912.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r6i1p1f1/Amon/psl/gn/v20200909/psl_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r6i1p1f1_gn_201911-202912.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r6i1p1f1/Amon/pr/gn/v20201205/pr_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r6i1p1f1_gn_201911-202912.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r7i1p1f1/day/tasmin/gn/v20201230/tasmin_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r7i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r7i1p1f1/day/pr/gn/v20201222/pr_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r7i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r7i1p1f1/day/tasmax/gn/v20201230/tasmax_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r7i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r7i1p1f1/AERday/zg500/gn/v20201225/zg500_AERday_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r7i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r7i1p1f1/Amon/tas/gn/v20200909/tas_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r7i1p1f1_gn_201911-202912.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r7i1p1f1/Amon/psl/gn/v20200909/psl_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r7i1p1f1_gn_201911-202912.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r7i1p1f1/Amon/pr/gn/v20210101/pr_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r7i1p1f1_gn_201911-202912.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r8i1p1f1/day/tasmin/gn/v20210111/tasmin_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r8i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r8i1p1f1/day/pr/gn/v20210107/pr_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r8i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r8i1p1f1/day/tasmax/gn/v20210111/tasmax_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r8i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r8i1p1f1/AERday/zg500/gn/v20210107/zg500_AERday_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r8i1p1f1_gn_20191101-20291231.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r8i1p1f1/Amon/tas/gn/v20200909/tas_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r8i1p1f1_gn_201911-202912.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r8i1p1f1/Amon/psl/gn/v20200909/psl_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r8i1p1f1_gn_201911-202912.nc
# C3S-CMIP6/DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r8i1p1f1/Amon/pr/gn/v20210102/pr_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r8i1p1f1_gn_201911-202912.nc
# ```

# %%
drop_list = [
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r10i1p1f1/day/tasmin/gn/v20210130/tasmin_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r10i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r10i1p1f1/day/pr/gn/v20210128/pr_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r10i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r10i1p1f1/day/tasmax/gn/v20210130/tasmax_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r10i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r10i1p1f1/AERday/zg500/gn/v20210128/zg500_AERday_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r10i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r10i1p1f1/Amon/tas/gn/v20200909/tas_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r10i1p1f1_gn_201911-202912.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r10i1p1f1/Amon/psl/gn/v20200909/psl_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r10i1p1f1_gn_201911-202912.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r10i1p1f1/Amon/pr/gn/v20210122/pr_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r10i1p1f1_gn_201911-202912.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r9i1p1f1/day/tasmin/gn/v20210121/tasmin_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r9i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r9i1p1f1/day/pr/gn/v20210119/pr_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r9i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r9i1p1f1/day/tasmax/gn/v20210121/tasmax_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r9i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r9i1p1f1/AERday/zg500/gn/v20210119/zg500_AERday_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r9i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r9i1p1f1/Amon/tas/gn/v20200909/tas_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r9i1p1f1_gn_201911-202912.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r9i1p1f1/Amon/psl/gn/v20200909/psl_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r9i1p1f1_gn_201911-202912.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r9i1p1f1/Amon/pr/gn/v20210121/pr_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r9i1p1f1_gn_201911-202912.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r6i1p1f1/day/tasmin/gn/v20201207/tasmin_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r6i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r6i1p1f1/day/pr/gn/v20201217/pr_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r6i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r6i1p1f1/day/tasmax/gn/v20201207/tasmax_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r6i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r6i1p1f1/AERday/zg500/gn/v20201213/zg500_AERday_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r6i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r6i1p1f1/Amon/tas/gn/v20200909/tas_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r6i1p1f1_gn_201911-202912.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r6i1p1f1/Amon/psl/gn/v20200909/psl_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r6i1p1f1_gn_201911-202912.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r6i1p1f1/Amon/pr/gn/v20201205/pr_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r6i1p1f1_gn_201911-202912.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r7i1p1f1/day/tasmin/gn/v20201230/tasmin_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r7i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r7i1p1f1/day/pr/gn/v20201222/pr_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r7i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r7i1p1f1/day/tasmax/gn/v20201230/tasmax_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r7i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r7i1p1f1/AERday/zg500/gn/v20201225/zg500_AERday_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r7i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r7i1p1f1/Amon/tas/gn/v20200909/tas_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r7i1p1f1_gn_201911-202912.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r7i1p1f1/Amon/psl/gn/v20200909/psl_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r7i1p1f1_gn_201911-202912.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r7i1p1f1/Amon/pr/gn/v20210101/pr_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r7i1p1f1_gn_201911-202912.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r8i1p1f1/day/tasmin/gn/v20210111/tasmin_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r8i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r8i1p1f1/day/pr/gn/v20210107/pr_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r8i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r8i1p1f1/day/tasmax/gn/v20210111/tasmax_day_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r8i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r8i1p1f1/AERday/zg500/gn/v20210107/zg500_AERday_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r8i1p1f1_gn_20191101-20291231.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r8i1p1f1/Amon/tas/gn/v20200909/tas_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r8i1p1f1_gn_201911-202912.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r8i1p1f1/Amon/psl/gn/v20200909/psl_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r8i1p1f1_gn_201911-202912.nc",
"DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2019-r8i1p1f1/Amon/pr/gn/v20210102/pr_Amon_MPI-ESM1-2-HR_dcppA-hindcast_s2019-r8i1p1f1_gn_201911-202912.nc",
]

# %%
df_new = df_cmip6_decadal

for p in drop_list:
    df_new = df_new.loc[df_new.path != p]
df_new
# Out:
#                                                     ds_id  \
# 0       c3s-cmip6-decadal.DCPP.MPI-M.MPI-ESM1-2-HR.dcp...
# 1       c3s-cmip6-decadal.DCPP.MPI-M.MPI-ESM1-2-HR.dcp...
# 2       c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
# 3       c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
# 4       c3s-cmip6-decadal.DCPP.MOHC.HadGEM3-GC31-MM.dc...
# ...                                                   ...
# 128680  c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
# 128681  c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
# 128682  c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
# 128683  c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
# 128684  c3s-cmip6-decadal.DCPP.EC-Earth-Consortium.EC-...
#
#                                                      path       size  \
# 0       DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2016-...  492479692
# 1       DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2009-...  737204109
# ...

# %%
df = df_new.loc[df_new.institution_id == 'MPI-M']
df.nunique()
# Out:
# ds_id              4130
# path               4130
# size               4105
# mip_era               1
# activity_id           1
# institution_id        1
# source_id             1
# experiment_id         1
# member_id           590
# table_id              3
# variable_id           6
# grid_label            1
# version              31
# start_time          118
# end_time            118
# bbox                  1
# level                 2
# member_year          59
# member_ensemble      10
# prefix                1
# dtype: int64

# %% [markdown]
# ## Write new catalog

# %%
from datetime import datetime

last_updated = datetime.now().utcnow()
version = last_updated.strftime('v%Y%m%d')
cat_name = f"c3s-cmip6-decadal_{version}.csv.gz"
cat_path = f"../intake/catalogs/c3s-cmip6-decadal/{cat_name}"

df_new.to_csv(cat_path, index=False, compression="gzip")
