# %% [markdown]
# # Update cordex manifest file from intake catalog

# %%
import intake
import pandas as pd
import datetime

# %%
# cat_url = "https://raw.githubusercontent.com/cp4cds/c3s_34g_manifests/master/intake/catalogs/c3s.yaml"
cat_url = "https://raw.githubusercontent.com/cp4cds/c3s_34g_manifests/refs/heads/update-cordex-2025-07-12/intake/catalogs/c3s.yaml"

cat = intake.open_catalog(cat_url)
cats = list(cat)
cats
# Out:
# ['c3s-cmip5',
#  'c3s-cmip5-daily-pressure-level',
#  'c3s-cmip5-daily-single-level',
#  'c3s-cmip5-monthly-pressure-level',
#  'c3s-cmip5-monthly-single-level',
#  'c3s-cmip6',
#  'c3s-cmip6-decadal',
#  'c3s-cordex',
#  'c3s-ipcc-atlas',
#  'c3s-cica-atlas-v01',
#  'c3s-cica-atlas']

# %% [markdown]
# ## Update cordex manifest

# %%
df_cordex = cat["c3s-cordex"].read()

# %%
df_cordex
# Out:
#                                                     ds_id  \
# 0       c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
# 1       c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
# 2       c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
# 3       c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
# 4       c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
# ...                                                   ...
# 568400  c3s-cordex.output.AFR-22.CCCma.CCCma-CanESM2.h...
# 568401  c3s-cordex.output.AFR-22.CCCma.CCCma-CanESM2.h...
# 568402  c3s-cordex.output.AFR-22.CCCma.CCCma-CanESM2.h...
# 568403  c3s-cordex.output.AFR-22.CCCma.CCCma-CanESM2.h...
# 568404  c3s-cordex.output.AFR-22.CCCma.CCCma-CanESM2.h...
#
#                                                      path  size     project  \
# 0       output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...   NaN  c3s-cordex
# 1       output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...   NaN  c3s-cordex
# 2       output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...   NaN  c3s-cordex
# 3       output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...   NaN  c3s-cordex
# 4       output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...   NaN  c3s-cordex
# ...                                                   ...   ...         ...
# 568400  output/AFR-22/CCCma/CCCma-CanESM2/historical/r...   NaN  c3s-cordex
# 568401  output/AFR-22/CCCma/CCCma-CanESM2/historical/r...   NaN  c3s-cordex
# 568402  output/AFR-22/CCCma/CCCma-CanESM2/historical/r...   NaN  c3s-cordex
# 568403  output/AFR-22/CCCma/CCCma-CanESM2/historical/r...   NaN  c3s-cordex
# 568404  output/AFR-22/CCCma/CCCma-CanESM2/historical/r...   NaN  c3s-cordex
#
#         domain institute  driving_model experiment_id ensemble       rcm_name  \
# 0       ARC-44      UQAM   ECMWF-ERAINT    evaluation   r1i1p1     UQAM-CRCM5
# 1       ARC-44      UQAM   ECMWF-ERAINT    evaluation   r1i1p1     UQAM-CRCM5
# 2       ARC-44      UQAM   ECMWF-ERAINT    evaluation   r1i1p1     UQAM-CRCM5
# 3       ARC-44      UQAM   ECMWF-ERAINT    evaluation   r1i1p1     UQAM-CRCM5
# 4       ARC-44      UQAM   ECMWF-ERAINT    evaluation   r1i1p1     UQAM-CRCM5
# ...        ...       ...            ...           ...      ...            ...
# 568400  AFR-22     CCCma  CCCma-CanESM2    historical   r1i1p1  CCCma-CanRCM4
# 568401  AFR-22     CCCma  CCCma-CanESM2    historical   r1i1p1  CCCma-CanRCM4
# 568402  AFR-22     CCCma  CCCma-CanESM2    historical   r1i1p1  CCCma-CanRCM4
# 568403  AFR-22     CCCma  CCCma-CanESM2    historical   r1i1p1  CCCma-CanRCM4
# 568404  AFR-22     CCCma  CCCma-CanESM2    historical   r1i1p1  CCCma-CanRCM4
#
#        rcm_version time_frequency variable    version           start_time  \
# 0               v1             fx    sftlf  v20200915                  NaN
# 1               v1             fx     orog  v20200915                  NaN
# 2               v1            day      clt  v20200915  1981-01-01T00:00:00
# 3               v1            day      clt  v20200915  1991-01-01T00:00:00
# 4               v1            day      clt  v20200915  2001-01-01T00:00:00
# ...            ...            ...      ...        ...                  ...
# 568400          r2            day   tasmin  v20201015  1986-01-01T00:00:00
# 568401          r2            day   tasmin  v20201015  1961-01-01T00:00:00
# 568402          r2            day   tasmin  v20201015  1966-01-01T00:00:00
# 568403          r2            day   tasmin  v20201015  1950-01-01T00:00:00
# 568404          r2            day   tasmin  v20201015  1996-01-01T00:00:00
#
#                    end_time  bbox level  \
# 0                       NaN   NaN   NaN
# 1                       NaN   NaN   NaN
# 2       1985-12-31T00:00:00   NaN   NaN
# 3       1995-12-31T00:00:00   NaN   NaN
# 4       2005-12-31T00:00:00   NaN   NaN
# ...                     ...   ...   ...
# 568400  1990-12-31T00:00:00   NaN   NaN
# 568401  1965-12-31T00:00:00   NaN   NaN
# 568402  1970-12-31T00:00:00   NaN   NaN
# 568403  1950-12-31T00:00:00   NaN   NaN
# 568404  2000-12-31T00:00:00   NaN   NaN
#
#                                                       url
# 0       https://data.mips.climate.copernicus.eu/thredd...
# 1       https://data.mips.climate.copernicus.eu/thredd...
# 2       https://data.mips.climate.copernicus.eu/thredd...
# 3       https://data.mips.climate.copernicus.eu/thredd...
# 4       https://data.mips.climate.copernicus.eu/thredd...
# ...                                                   ...
# 568400  https://data.mips.climate.copernicus.eu/thredd...
# 568401  https://data.mips.climate.copernicus.eu/thredd...
# 568402  https://data.mips.climate.copernicus.eu/thredd...
# 568403  https://data.mips.climate.copernicus.eu/thredd...
# 568404  https://data.mips.climate.copernicus.eu/thredd...
#
# [568405 rows x 19 columns]

# %%
cds_domain = "data.mips.climate.copernicus.eu"
base_url = f"https://{cds_domain}/thredds/fileServer/esg_c3s-cordex"

df_cordex["url"] = df_cordex["path"].apply(lambda x: f"{base_url}/{x}")

# %%
list(df_cordex["url"])[0]
# Out:
# 'https://data.mips.climate.copernicus.eu/thredds/fileServer/esg_c3s-cordex/output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i1p1/UQAM-CRCM5/v1/fx/sftlf/v20200915/sftlf_ARC-44_ECMWF-ERAINT_evaluation_r1i1p1_UQAM-CRCM5_v1_fx.nc'

# %%
last_updated = datetime.datetime.now(datetime.UTC)
version = last_updated.strftime('%Y%m%d')
manifest_path = f"../cordex/manifest_C3S_CORDEX_{version}.txt.gz"

df_cordex.to_csv(manifest_path, columns=["url"], header=False, index=False, compression="gzip")
