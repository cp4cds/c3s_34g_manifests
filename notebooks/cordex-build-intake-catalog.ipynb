# %% [markdown]
# # Build intake catalog for CORDEX datasets
#
# date: 2025.07.12

# %%
import pandas as pd
import numpy as np

# %%
## load manifest

df = pd.read_csv("../cordex/IPSL_manifest_C3S_CORDEX_20250709.txt.gz", names=["url"])
df
# Out:
#                                                       url
# 0       https://data.mips.climate.copernicus.eu/thredd...
# 1       https://data.mips.climate.copernicus.eu/thredd...
# 2       https://data.mips.climate.copernicus.eu/thredd...
# 3       https://data.mips.climate.copernicus.eu/thredd...
# 4       https://data.mips.climate.copernicus.eu/thredd...
# ...                                                   ...
# 568400  https://data.mips.climate.copernicus.eu/thredd...
# 568401  https://data.mips.climate.copernicus.eu/thredd...
# 568402  https://data.mips.climate.copernicus.eu/thredd...
# 568403  https://data.mips.climate.copernicus.eu/thredd...
# 568404  https://data.mips.climate.copernicus.eu/thredd...
#
# [568405 rows x 1 columns]

# %%
df.url[0]
# Out:
# 'https://data.mips.climate.copernicus.eu/thredds/fileServer/esg_c3s-cordex/output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i1p1/UQAM-CRCM5/v1/fx/sftlf/v20200915/sftlf_ARC-44_ECMWF-ERAINT_evaluation_r1i1p1_UQAM-CRCM5_v1_fx.nc'

# %%
## build new dataframe

df_new = pd.DataFrame(columns = [
    'ds_id',
    'path',
    'size',
    'project',
    'domain',
    'institute',
    'driving_model',
    'experiment_id',
    'ensemble',
    'rcm_name',
    'rcm_version',
    'time_frequency',
    'variable',
    'version',   
    'start_time',
    'end_time',
    'bbox',
    'level',
    'url'
])
df_new
# Out:
# Empty DataFrame
# Columns: [ds_id, path, size, project, domain, institute, driving_model, experiment_id, ensemble, rcm_name, rcm_version, time_frequency, variable, version, start_time, end_time, bbox, level, url]
# Index: []

# %%
df_new["url"] = df["url"]
df_new.head()
# Out:
#   ds_id path size project domain institute driving_model experiment_id  \
# 0   NaN  NaN  NaN     NaN    NaN       NaN           NaN           NaN
# 1   NaN  NaN  NaN     NaN    NaN       NaN           NaN           NaN
# 2   NaN  NaN  NaN     NaN    NaN       NaN           NaN           NaN
# 3   NaN  NaN  NaN     NaN    NaN       NaN           NaN           NaN
# 4   NaN  NaN  NaN     NaN    NaN       NaN           NaN           NaN
#
#   ensemble rcm_name rcm_version time_frequency variable version start_time  \
# 0      NaN      NaN         NaN            NaN      NaN     NaN        NaN
# 1      NaN      NaN         NaN            NaN      NaN     NaN        NaN
# 2      NaN      NaN         NaN            NaN      NaN     NaN        NaN
# 3      NaN      NaN         NaN            NaN      NaN     NaN        NaN
# 4      NaN      NaN         NaN            NaN      NaN     NaN        NaN
#
#   end_time bbox level                                                url
# 0      NaN  NaN   NaN  https://data.mips.climate.copernicus.eu/thredd...
# 1      NaN  NaN   NaN  https://data.mips.climate.copernicus.eu/thredd...
# 2      NaN  NaN   NaN  https://data.mips.climate.copernicus.eu/thredd...
# 3      NaN  NaN   NaN  https://data.mips.climate.copernicus.eu/thredd...
# 4      NaN  NaN   NaN  https://data.mips.climate.copernicus.eu/thredd...

# %%
df_new["path"] = df_new["url"].str.replace("https://data.mips.climate.copernicus.eu/thredds/fileServer/esg_c3s-cordex/", "", regex=False)
df_new.head()
# Out:
#   ds_id                                               path size project  \
# 0   NaN  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN     NaN
# 1   NaN  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN     NaN
# 2   NaN  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN     NaN
# 3   NaN  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN     NaN
# 4   NaN  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN     NaN
#
#   domain institute driving_model experiment_id ensemble rcm_name rcm_version  \
# 0    NaN       NaN           NaN           NaN      NaN      NaN         NaN
# 1    NaN       NaN           NaN           NaN      NaN      NaN         NaN
# 2    NaN       NaN           NaN           NaN      NaN      NaN         NaN
# 3    NaN       NaN           NaN           NaN      NaN      NaN         NaN
# 4    NaN       NaN           NaN           NaN      NaN      NaN         NaN
#
#   time_frequency variable version start_time end_time bbox level  \
# 0            NaN      NaN     NaN        NaN      NaN  NaN   NaN
# 1            NaN      NaN     NaN        NaN      NaN  NaN   NaN
# 2            NaN      NaN     NaN        NaN      NaN  NaN   NaN
# 3            NaN      NaN     NaN        NaN      NaN  NaN   NaN
# 4            NaN      NaN     NaN        NaN      NaN  NaN   NaN
#
#                                                  url
# 0  https://data.mips.climate.copernicus.eu/thredd...
# 1  https://data.mips.climate.copernicus.eu/thredd...
# 2  https://data.mips.climate.copernicus.eu/thredd...
# 3  https://data.mips.climate.copernicus.eu/thredd...
# 4  https://data.mips.climate.copernicus.eu/thredd...

# %%
df_new.path[0]
# Out:
# 'output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i1p1/UQAM-CRCM5/v1/fx/sftlf/v20200915/sftlf_ARC-44_ECMWF-ERAINT_evaluation_r1i1p1_UQAM-CRCM5_v1_fx.nc'

# %%
# 'c3s-cordex.output.EUR-11.MOHC.MOHC-HadGEM2-ES.rcp85.r1i1p1.MOHC-HadREM3-GA7-05.v1.mon.tas.v20200330'


df_new["ds_id"] = df_new["path"].apply(lambda x: 'c3s-cordex.' + '.'.join(x.split('/')[0:-1]))
df_new.head()
# Out:
#                                                ds_id  \
# 0  c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
# 1  c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
# 2  c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
# 3  c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
# 4  c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
#
#                                                 path size project domain  \
# 0  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN     NaN    NaN
# 1  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN     NaN    NaN
# 2  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN     NaN    NaN
# 3  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN     NaN    NaN
# 4  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN     NaN    NaN
#
#   institute driving_model experiment_id ensemble rcm_name rcm_version  \
# 0       NaN           NaN           NaN      NaN      NaN         NaN
# 1       NaN           NaN           NaN      NaN      NaN         NaN
# 2       NaN           NaN           NaN      NaN      NaN         NaN
# 3       NaN           NaN           NaN      NaN      NaN         NaN
# 4       NaN           NaN           NaN      NaN      NaN         NaN
#
#   time_frequency variable version start_time end_time bbox level  \
# 0            NaN      NaN     NaN        NaN      NaN  NaN   NaN
# 1            NaN      NaN     NaN        NaN      NaN  NaN   NaN
# 2            NaN      NaN     NaN        NaN      NaN  NaN   NaN
# 3            NaN      NaN     NaN        NaN      NaN  NaN   NaN
# 4            NaN      NaN     NaN        NaN      NaN  NaN   NaN
#
#                                                  url
# 0  https://data.mips.climate.copernicus.eu/thredd...
# 1  https://data.mips.climate.copernicus.eu/thredd...
# 2  https://data.mips.climate.copernicus.eu/thredd...
# 3  https://data.mips.climate.copernicus.eu/thredd...
# 4  https://data.mips.climate.copernicus.eu/thredd...

# %%
df_new.ds_id[0]
# Out:
# 'c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.evaluation.r1i1p1.UQAM-CRCM5.v1.fx.sftlf.v20200915'

# %%
def get_project(ds_id):
    value = ds_id.split('.')[0]
    return value

def get_domain(ds_id):
    value = ds_id.split(".")[2]
    return value

def get_institute(ds_id):
    value = ds_id.split(".")[3]
    return value

def get_driving_model(ds_id):
    value = ds_id.split(".")[4]
    return value

def get_experiment_id(ds_id):
    value = ds_id.split(".")[5]
    return value

def get_ensemble(ds_id):
    value = ds_id.split(".")[6]
    return value

def get_rcm_name(ds_id):
    value = ds_id.split(".")[7]
    return value

def get_rcm_version(ds_id):
    value = ds_id.split(".")[8]
    return value

def get_time_frequency(ds_id):
    value = ds_id.split(".")[9]
    return value

def get_variable(ds_id):
    value = ds_id.split(".")[10]
    return value

def get_version(ds_id):
    value = ds_id.split('.')[11]
    return value
    
def get_start_time(path):
    parts = path.split("_")
    part = parts[-2]
    start = part.split("-")[0]
    if "mon" in parts:
        start_time = f"{start[0:4]}-{start[4:6]}-01T00:00:00"
    else:
        start_time = f"{start[0:4]}-01-01T00:00:00"
    return start_time

def get_end_time(path):
    # ['fx', 'day', 'mon', '6hr', '3hr', 'sem']
    # print(path)
    filename = path.split("/")[-1]
    # print(filename)
    name = filename.split(".nc")[0]
    # print(name)
    parts = name.split("_")
    # print(parts)
    
    if "fx" in parts:
        end_time = ""
        return end_time
    
    date_part = parts[-1]
    end = date_part.split("-")[-1]
    if "day" in parts:
        end_time = f"{end[0:4]}-{end[4:6]}-{end[6:7]}T00:00:00"
    elif "mon" in parts:
        end_time = f"{end[0:4]}-{end[4:6]}-31T00:00:00"
    else:
        end_time = f"{end[0:4]}-12-31T00:00:00"
    return end_time

# %%
df_new['project'] = df_new["ds_id"].apply(get_project)
df_new['domain'] = df_new["ds_id"].apply(get_domain)
df_new['institute'] = df_new["ds_id"].apply(get_institute)
df_new['driving_model'] = df_new["ds_id"].apply(get_driving_model)
df_new['experiment_id'] = df_new["ds_id"].apply(get_experiment_id)
df_new['ensemble'] = df_new["ds_id"].apply(get_ensemble)
df_new['rcm_name'] = df_new["ds_id"].apply(get_rcm_name)
df_new['rcm_version'] = df_new["ds_id"].apply(get_rcm_version)
df_new['time_frequency'] = df_new["ds_id"].apply(get_time_frequency)
df_new['variable'] = df_new["ds_id"].apply(get_variable)
df_new['version'] = df_new['ds_id'].apply(get_version)
#df_new['start_time'] = df_new["path"].apply(get_start_time)
df_new['end_time'] = df_new["path"].apply(get_end_time)
df_new.head()
# Out:
#                                                ds_id  \
# 0  c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
# 1  c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
# 2  c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
# 3  c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
# 4  c3s-cordex.output.ARC-44.UQAM.ECMWF-ERAINT.eva...
#
#                                                 path size     project  domain  \
# 0  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN  c3s-cordex  ARC-44
# 1  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN  c3s-cordex  ARC-44
# 2  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN  c3s-cordex  ARC-44
# 3  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN  c3s-cordex  ARC-44
# 4  output/ARC-44/UQAM/ECMWF-ERAINT/evaluation/r1i...  NaN  c3s-cordex  ARC-44
#
#   institute driving_model experiment_id ensemble    rcm_name rcm_version  \
# 0      UQAM  ECMWF-ERAINT    evaluation   r1i1p1  UQAM-CRCM5          v1
# 1      UQAM  ECMWF-ERAINT    evaluation   r1i1p1  UQAM-CRCM5          v1
# 2      UQAM  ECMWF-ERAINT    evaluation   r1i1p1  UQAM-CRCM5          v1
# 3      UQAM  ECMWF-ERAINT    evaluation   r1i1p1  UQAM-CRCM5          v1
# 4      UQAM  ECMWF-ERAINT    evaluation   r1i1p1  UQAM-CRCM5          v1
#
#   time_frequency variable    version start_time            end_time bbox  \
# 0             fx    sftlf  v20200915        NaN                      NaN
# 1             fx     orog  v20200915        NaN                      NaN
# 2            day      clt  v20200915        NaN  1985-12-3T00:00:00  NaN
# 3            day      clt  v20200915        NaN  1995-12-3T00:00:00  NaN
# 4            day      clt  v20200915        NaN  2005-12-3T00:00:00  NaN
#
#   level                                                url
# 0   NaN  https://data.mips.climate.copernicus.eu/thredd...
# 1   NaN  https://data.mips.climate.copernicus.eu/thredd...
# 2   NaN  https://data.mips.climate.copernicus.eu/thredd...
# 3   NaN  https://data.mips.climate.copernicus.eu/thredd...
# 4   NaN  https://data.mips.climate.copernicus.eu/thredd...

# %% [markdown]
# ## show values

# %%
df_new.nunique()
# Out:
# ds_id              23488
# path              568405
# size                   0
# project                1
# domain                27
# institute             39
# driving_model         17
# experiment_id          5
# ensemble               6
# rcm_name              56
# rcm_version           11
# time_frequency         6
# variable              25
# version              144
# start_time             0
# end_time             470
# bbox                   0
# level                  0
# url               568405
# dtype: int64

# %%
versions = list(df_new["version"].unique())
versions.sort()
versions
# Out:
# ['v20131026',
#  'v20131119',
#  'v20140218',
#  'v20140313',
#  'v20140319',
#  'v20140324',
#  'v20140402',
#  'v20140515',
#  'v20140620',
#  'v20140826',
#  'v20140917',
#  'v20141024',
#  'v20141216',
#  'v20150114',
#  'v20150127',
#  'v20150320',
#  'v20150421',
#  'v20160419',
#  'v20160525',
#  'v20160620',
#  'v20160704',
#  'v20160705',
#  'v20160803',
#  'v20160830',
#  'v20170206',
#  'v20170208',
#  'v20170329',
#  'v20170410',
#  'v20170412',
#  'v20170504',
#  'v20170523',
#  'v20170524',
#  'v20170606',
#  'v20170713',
#  'v20171121',
#  'v20180212',
#  'v20180220',
#  'v20180226',
#  'v20180509',
#  'v20180707',
#  'v20180710',
#  'v20180717',
#  'v20180813',
#  'v20180820',
#  'v20181107',
#  'v20181126',
#  'v20181203',
#  'v20181212',
#  'v20190103',
#  'v20190108',
#  'v20190115',
#  'v20190131',
#  'v20190208',
#  'v20190212',
#  'v20190304',
#  'v20190412',
#  'v20190415',
#  'v20190418',
#  'v20190419',
#  'v20190502',
#  'v20190509',
#  'v20190510',
#  'v20190512',
#  'v20190522',
#  'v20190619',
#  'v20190620',
#  'v20190625',
#  'v20190702',
#  'v20190805',
#  'v20190806',
#  'v20190809',
#  'v20190814',
#  'v20190816',
#  'v20190820',
#  'v20190828',
#  'v20190919',
#  'v20190924',
#  'v20190925',
#  'v20190926',
#  'v20191001',
#  'v20191004',
#  'v20191015',
#  'v20191029',
#  'v20191101',
#  'v20191105',
#  'v20191116',
#  'v20191118',
#  'v20191119',
#  'v20191129',
#  'v20191210',
#  'v20191217',
#  'v20191219',
#  'v20200102',
#  'v20200113',
#  'v20200117',
#  'v20200211',
#  'v20200221',
#  'v20200229',
#  'v20200306',
#  'v20200330',
#  'v20200424',
#  'v20200515',
#  'v20200518',
#  'v20200525',
#  'v20200609',
#  'v20200623',
#  'v20200702',
#  'v20200706',
#  'v20200713',
#  'v20200716',
#  'v20200831',
#  'v20200901',
#  'v20200915',
#  'v20200921',
#  'v20200924',
#  'v20200925',
#  'v20201001',
#  'v20201009',
#  'v20201015',
#  'v20201031',
#  'v20201101',
#  'v20201110',
#  'v20201111',
#  'v20201112',
#  'v20201120',
#  'v20201201',
#  'v20201203',
#  'v20201209',
#  'v20201215',
#  'v20201220',
#  'v20201231',
#  'v20210111',
#  'v20210113',
#  'v20210120',
#  'v20210128',
#  'v20210131',
#  'v20210222',
#  'v20210301',
#  'v20210308',
#  'v20210405',
#  'v20210415',
#  'v20210430',
#  'v20210505',
#  'v20220404']

# %%
list(df_new.project.unique())
# Out:
# ['c3s-cordex']

# %%
list(df_new.domain.unique())
# Out:
# ['ARC-44',
#  'ARC-22',
#  'SAM-22',
#  'NAM-44',
#  'AUS-44',
#  'ANT-44',
#  'MED-44',
#  'AFR-44',
#  'MNA-44',
#  'EAS-22',
#  'MED-11',
#  'AUS-44i',
#  'WAS-22',
#  'NAM-22',
#  'CAS-44',
#  'WAS-44',
#  'EUR-11',
#  'CAS-22',
#  'SAM-20',
#  'SEA-22',
#  'AUS-22',
#  'CAM-44',
#  'CAM-22',
#  'SAM-44',
#  'MNA-22',
#  'EAS-44',
#  'AFR-22']

# %%
list(df_new.driving_model.unique())
# Out:
# ['ECMWF-ERAINT',
#  'CCCma-CanESM2',
#  'MPI-M-MPI-ESM-MR',
#  'MPI-M-MPI-ESM-LR',
#  'ICHEC-EC-EARTH',
#  'NCC-NorESM1-M',
#  'MOHC-HadGEM2-ES',
#  'NOAA-GFDL-GFDL-ESM2M',
#  'CSIRO-BOM-ACCESS1-0',
#  'CSIRO-BOM-ACCESS1-3',
#  'IPSL-IPSL-CM5A-MR',
#  'CNRM-CERFACS-CNRM-CM5',
#  'MIROC-MIROC5',
#  'IPSL-IPSL-CM5A-LR',
#  'NOAA-GFDL-GFDL-ESM2G',
#  'CSIRO-QCCCE-CSIRO-Mk3-6-0',
#  'NCAR-CCSM4']

# %%
list(df_new.experiment_id.unique())
# Out:
# ['evaluation', 'rcp85', 'historical', 'rcp45', 'rcp26']

# %%
list(df_new.ensemble.unique())
# Out:
# ['r1i1p1', 'r0i0p0', 'r12i1p1', 'r3i1p1', 'r2i1p1', 'r6i1p1']

# %%
list(df_new.rcm_name.unique())
# Out:
# ['UQAM-CRCM5',
#  'UQAM-CRCM5-SN',
#  'BCCR-WRF331',
#  'CCCma-CanRCM4',
#  'MGO-RRCM',
#  'ULg-MAR36',
#  'SMHI-RCA4',
#  'SMHI-RCA4-SN',
#  'AWI-HIRHAM5',
#  'DMI-HIRHAM5',
#  'ICTP-RegCM4-7',
#  'GERICS-REMO2015',
#  'ISU-RegCM4',
#  'NCAR-RegCM4',
#  'NCAR-WRF',
#  'UA-WRF',
#  'UNSW-WRF360K',
#  'UNSW-WRF360L',
#  'UNSW-WRF360J',
#  'CLMcom-CCLM4-8-17-CLM3-5',
#  'KNMI-RACMO21P',
#  'ULg-MAR311',
#  'GUF-CCLM4-8-18',
#  'LMD-LMDZ4NEMOMED8',
#  'ICTP-RegCM4-3',
#  'ELU-RegCM4-3',
#  'CNRM-ALADIN52',
#  'CMCC-CCLM4-8-19',
#  'MPI-CSC-REMO2009',
#  'GERICS-REMO2009',
#  'CLMcom-CCLM4-8-17',
#  'KNMI-RACMO22T',
#  'BOUN-RegCM4-3',
#  'CYI-WRF351',
#  'ICTP-RegCM4-4',
#  'CSIRO-CCAM-2008',
#  'ORNL-RegCM4-7',
#  'CLMcom-ETH-COSMO-crCLIM-v1-1',
#  'OURANOS-CRCM5',
#  'IITM-RegCM4-4',
#  'MOHC-HadRM3P',
#  'ICTP-RegCM4-6',
#  'CLMcom-BTU-CCLM4-8-17',
#  'IPSL-WRF381P',
#  'CNRM-ALADIN63',
#  'CNRM-ALADIN53',
#  'UHOH-WRF361H',
#  'KNMI-RACMO22E',
#  'MOHC-HadREM3-GA7-05',
#  'RMIB-UGent-ALARO-0',
#  'INPE-Eta',
#  'RU-CORE-RegCM4-3',
#  'CLMcom-HZG-CCLM5-0-15',
#  'UCAN-WRF341I',
#  'CLMcom-CCLM5-0-2',
#  'CLMcom-KIT-CCLM5-0-15']

# %%
list(df_new.rcm_version.unique())
# Out:
# ['v1', 'r2', 'v2', 'v0', 'v4-4-rc8', 'v3-5-1', 'v7', 'v4', 'v5', 'v1a', 'v3']

# %%
list(df_new.time_frequency.unique())
# Out:
# ['fx', 'day', 'mon', '6hr', '3hr', 'sem']

# %%
list(df_new.variable.unique())
# Out:
# ['sftlf',
#  'orog',
#  'clt',
#  'uas',
#  'rlds',
#  'pr',
#  'psl',
#  'ps',
#  'rsds',
#  'tasmax',
#  'huss',
#  'vas',
#  'tas',
#  'tasmin',
#  'sfcWind',
#  'evspsbl',
#  'hurs',
#  'ua850',
#  'rsus',
#  'va850',
#  'zg500',
#  'mrro',
#  'ua200',
#  'va200',
#  'ta200']

# %%
list(df_new.start_time.unique())
# Out:
# [nan]

# %%
list(df_new.end_time.unique())
# Out:
# ['',
#  '1985-12-3T00:00:00',
#  '1995-12-3T00:00:00',
#  '2005-12-3T00:00:00',
#  '2010-12-3T00:00:00',
#  '1980-12-3T00:00:00',
#  '2000-12-3T00:00:00',
#  '1990-12-3T00:00:00',
#  '2014-12-3T00:00:00',
#  '2015-12-3T00:00:00',
#  '2070-12-3T00:00:00',
#  '2045-12-3T00:00:00',
#  '2085-12-3T00:00:00',
#  '2060-12-3T00:00:00',
#  '2025-12-3T00:00:00',
#  '2100-12-3T00:00:00',
#  '2040-12-3T00:00:00',
#  '2075-12-3T00:00:00',
#  '2055-12-3T00:00:00',
#  '2050-12-3T00:00:00',
#  '2095-12-3T00:00:00',
#  '2020-12-3T00:00:00',
#  '2030-12-3T00:00:00',
#  '2065-12-3T00:00:00',
#  '2090-12-3T00:00:00',
#  '2035-12-3T00:00:00',
#  '2080-12-3T00:00:00',
#  '1960-12-3T00:00:00',
#  '1965-12-3T00:00:00',
#  '1950-12-3T00:00:00',
#  '1970-12-3T00:00:00',
#  '1955-12-3T00:00:00',
#  '1975-12-3T00:00:00',
#  '2009-12-3T00:00:00',
#  '1987-12-3T00:00:00',
#  '2008-12-3T00:00:00',
#  '2006-12-3T00:00:00',
#  '1981-12-3T00:00:00',
#  '1997-12-3T00:00:00',
#  '1984-12-3T00:00:00',
#  '1991-12-3T00:00:00',
#  '1996-12-3T00:00:00',
#  '2003-12-3T00:00:00',
#  '1993-12-3T00:00:00',
#  '2001-12-3T00:00:00',
#  '2011-12-3T00:00:00',
#  '2002-12-3T00:00:00',
#  '1988-12-3T00:00:00',
#  '1999-12-3T00:00:00',
#  '1992-12-3T00:00:00',
#  '1989-12-3T00:00:00',
#  '2013-12-3T00:00:00',
#  '2012-12-3T00:00:00',
#  '2007-12-3T00:00:00',
#  '1982-12-3T00:00:00',
#  '1979-12-3T00:00:00',
#  '2004-12-3T00:00:00',
#  '1994-12-3T00:00:00',
#  '1986-12-3T00:00:00',
#  '1983-12-3T00:00:00',
#  '1998-12-3T00:00:00',
#  '2076-12-3T00:00:00',
#  '2057-12-3T00:00:00',
#  '2096-12-3T00:00:00',
#  '2061-12-3T00:00:00',
#  '2032-12-3T00:00:00',
#  '2029-12-3T00:00:00',
#  '2051-12-3T00:00:00',
#  '2084-12-3T00:00:00',
#  '2072-12-3T00:00:00',
#  '2077-12-3T00:00:00',
#  '2017-12-3T00:00:00',
#  '2043-12-3T00:00:00',
#  '2018-12-3T00:00:00',
#  '2033-12-3T00:00:00',
#  '2094-12-3T00:00:00',
#  '2068-12-3T00:00:00',
#  '2042-12-3T00:00:00',
#  '2092-12-3T00:00:00',
#  '2082-12-3T00:00:00',
#  '2071-12-3T00:00:00',
#  '2083-12-3T00:00:00',
#  '2093-12-3T00:00:00',
#  '2022-12-3T00:00:00',
#  '2052-12-3T00:00:00',
#  '2062-12-3T00:00:00',
#  '2016-12-3T00:00:00',
#  '2067-12-3T00:00:00',
#  '2087-12-3T00:00:00',
#  '2024-12-3T00:00:00',
#  '2048-12-3T00:00:00',
#  '2047-12-3T00:00:00',
#  '2078-12-3T00:00:00',
#  '2074-12-3T00:00:00',
#  '2037-12-3T00:00:00',
#  '2044-12-3T00:00:00',
#  '2019-12-3T00:00:00',
#  '2049-12-3T00:00:00',
#  '2081-12-3T00:00:00',
#  '2041-12-3T00:00:00',
#  '2026-12-3T00:00:00',
#  '2073-12-3T00:00:00',
#  '2099-12-3T00:00:00',
#  '2056-12-3T00:00:00',
#  '2089-12-3T00:00:00',
#  '2063-12-3T00:00:00',
#  '2023-12-3T00:00:00',
#  '2053-12-3T00:00:00',
#  '2031-12-3T00:00:00',
#  '2027-12-3T00:00:00',
#  '2079-12-3T00:00:00',
#  '2054-12-3T00:00:00',
#  '2091-12-3T00:00:00',
#  '2098-12-3T00:00:00',
#  '2028-12-3T00:00:00',
#  '2034-12-3T00:00:00',
#  '2039-12-3T00:00:00',
#  '2021-12-3T00:00:00',
#  '2038-12-3T00:00:00',
#  '2066-12-3T00:00:00',
#  '2069-12-3T00:00:00',
#  '2086-12-3T00:00:00',
#  '2058-12-3T00:00:00',
#  '2064-12-3T00:00:00',
#  '2088-12-3T00:00:00',
#  '2036-12-3T00:00:00',
#  '2097-12-3T00:00:00',
#  '2046-12-3T00:00:00',
#  '2059-12-3T00:00:00',
#  '1972-12-3T00:00:00',
#  '1971-12-3T00:00:00',
#  '1976-12-3T00:00:00',
#  '1973-12-3T00:00:00',
#  '1974-12-3T00:00:00',
#  '1977-12-3T00:00:00',
#  '1978-12-3T00:00:00',
#  '2099-11-3T00:00:00',
#  '1953-12-3T00:00:00',
#  '1966-12-3T00:00:00',
#  '1963-12-3T00:00:00',
#  '1968-12-3T00:00:00',
#  '1956-12-3T00:00:00',
#  '1964-12-3T00:00:00',
#  '1959-12-3T00:00:00',
#  '1952-12-3T00:00:00',
#  '1969-12-3T00:00:00',
#  '1961-12-3T00:00:00',
#  '1958-12-3T00:00:00',
#  '1967-12-3T00:00:00',
#  '1962-12-3T00:00:00',
#  '1957-12-3T00:00:00',
#  '1954-12-3T00:00:00',
#  '1951-12-3T00:00:00',
#  '1949-12-3T00:00:00',
#  '2060-12-31T00:00:00',
#  '2070-12-31T00:00:00',
#  '2020-12-31T00:00:00',
#  '2090-12-31T00:00:00',
#  '2050-12-31T00:00:00',
#  '2040-12-31T00:00:00',
#  '2030-12-31T00:00:00',
#  '2010-12-31T00:00:00',
#  '2080-12-31T00:00:00',
#  '2100-12-31T00:00:00',
#  '1980-12-31T00:00:00',
#  '2000-12-31T00:00:00',
#  '1990-12-31T00:00:00',
#  '2005-12-31T00:00:00',
#  '1950-12-31T00:00:00',
#  '1960-12-31T00:00:00',
#  '1970-12-31T00:00:00',
#  '1979-12-31T00:00:00',
#  '1984-12-31T00:00:00',
#  '2007-12-31T00:00:00',
#  '1992-12-31T00:00:00',
#  '1991-12-31T00:00:00',
#  '2011-12-31T00:00:00',
#  '2001-12-31T00:00:00',
#  '2008-12-31T00:00:00',
#  '1987-12-31T00:00:00',
#  '1993-12-31T00:00:00',
#  '1998-12-31T00:00:00',
#  '2006-12-31T00:00:00',
#  '1986-12-31T00:00:00',
#  '1994-12-31T00:00:00',
#  '1996-12-31T00:00:00',
#  '2004-12-31T00:00:00',
#  '1989-12-31T00:00:00',
#  '2003-12-31T00:00:00',
#  '1997-12-31T00:00:00',
#  '1981-12-31T00:00:00',
#  '1988-12-31T00:00:00',
#  '1983-12-31T00:00:00',
#  '1982-12-31T00:00:00',
#  '1995-12-31T00:00:00',
#  '1999-12-31T00:00:00',
#  '2002-12-31T00:00:00',
#  '2009-12-31T00:00:00',
#  '1985-12-31T00:00:00',
#  '2012-11-3T00:00:00',
#  '2012-11-31T00:00:00',
#  '1993-01-0T00:00:00',
#  '2008-01-0T00:00:00',
#  '1989-01-0T00:00:00',
#  '1998-01-0T00:00:00',
#  '1994-01-0T00:00:00',
#  '2000-01-0T00:00:00',
#  '2001-01-0T00:00:00',
#  '1982-01-0T00:00:00',
#  '1984-01-0T00:00:00',
#  '1985-01-0T00:00:00',
#  '1988-01-0T00:00:00',
#  '1999-01-0T00:00:00',
#  '2007-01-0T00:00:00',
#  '1980-01-0T00:00:00',
#  '2008-12-0T00:00:00',
#  '2004-01-0T00:00:00',
#  '1981-01-0T00:00:00',
#  '1997-01-0T00:00:00',
#  '1995-01-0T00:00:00',
#  '1986-01-0T00:00:00',
#  '1990-01-0T00:00:00',
#  '2006-01-0T00:00:00',
#  '2002-01-0T00:00:00',
#  '1996-01-0T00:00:00',
#  '1992-01-0T00:00:00',
#  '1991-01-0T00:00:00',
#  '1983-01-0T00:00:00',
#  '1987-01-0T00:00:00',
#  '2005-01-0T00:00:00',
#  '2003-01-0T00:00:00',
#  '2072-01-0T00:00:00',
#  '2083-01-0T00:00:00',
#  '2060-01-0T00:00:00',
#  '2080-01-0T00:00:00',
#  '2016-01-0T00:00:00',
#  '2067-01-0T00:00:00',
#  '2049-01-0T00:00:00',
#  '2087-01-0T00:00:00',
#  '2058-01-0T00:00:00',
#  '2068-01-0T00:00:00',
#  '2022-01-0T00:00:00',
#  '2073-01-0T00:00:00',
#  '2076-01-0T00:00:00',
#  '2066-01-0T00:00:00',
#  '2069-01-0T00:00:00',
#  '2052-01-0T00:00:00',
#  '2021-01-0T00:00:00',
#  '2091-01-0T00:00:00',
#  '2047-01-0T00:00:00',
#  '2071-01-0T00:00:00',
#  '2037-01-0T00:00:00',
#  '2033-01-0T00:00:00',
#  '2086-01-0T00:00:00',
#  '2042-01-0T00:00:00',
#  '2065-01-0T00:00:00',
#  '2079-01-0T00:00:00',
#  '2094-01-0T00:00:00',
#  '2015-01-0T00:00:00',
#  '2055-01-0T00:00:00',
#  '2056-01-0T00:00:00',
#  '2039-01-0T00:00:00',
#  '2032-01-0T00:00:00',
#  '2040-01-0T00:00:00',
#  '2089-01-0T00:00:00',
#  '2096-01-0T00:00:00',
#  '2026-01-0T00:00:00',
#  '2085-01-0T00:00:00',
#  '2041-01-0T00:00:00',
#  '2012-01-0T00:00:00',
#  '2064-01-0T00:00:00',
#  '2093-01-0T00:00:00',
#  '2063-01-0T00:00:00',
#  '2028-01-0T00:00:00',
#  '2038-01-0T00:00:00',
#  '2078-01-0T00:00:00',
#  '2009-01-0T00:00:00',
#  '2011-01-0T00:00:00',
#  '2097-01-0T00:00:00',
#  '2062-01-0T00:00:00',
#  '2092-01-0T00:00:00',
#  '2054-01-0T00:00:00',
#  '2095-01-0T00:00:00',
#  '2074-01-0T00:00:00',
#  '2019-01-0T00:00:00',
#  '2034-01-0T00:00:00',
#  '2053-01-0T00:00:00',
#  '2082-01-0T00:00:00',
#  '2010-01-0T00:00:00',
#  '2088-01-0T00:00:00',
#  '2081-01-0T00:00:00',
#  '2048-01-0T00:00:00',
#  '2035-01-0T00:00:00',
#  '2014-01-0T00:00:00',
#  '2027-01-0T00:00:00',
#  '2029-01-0T00:00:00',
#  '2043-01-0T00:00:00',
#  '2017-01-0T00:00:00',
#  '2050-01-0T00:00:00',
#  '2077-01-0T00:00:00',
#  '2084-01-0T00:00:00',
#  '2100-01-0T00:00:00',
#  '2051-01-0T00:00:00',
#  '2057-01-0T00:00:00',
#  '2075-01-0T00:00:00',
#  '2023-01-0T00:00:00',
#  '2090-01-0T00:00:00',
#  '2031-01-0T00:00:00',
#  '2025-01-0T00:00:00',
#  '2018-01-0T00:00:00',
#  '2046-01-0T00:00:00',
#  '2030-01-0T00:00:00',
#  '2020-01-0T00:00:00',
#  '2013-01-0T00:00:00',
#  '2070-01-0T00:00:00',
#  '2061-01-0T00:00:00',
#  '2059-01-0T00:00:00',
#  '2099-01-0T00:00:00',
#  '2044-01-0T00:00:00',
#  '2098-01-0T00:00:00',
#  '2036-01-0T00:00:00',
#  '2024-01-0T00:00:00',
#  '2045-01-0T00:00:00',
#  '2100-01-31T00:00:00',
#  '2025-01-31T00:00:00',
#  '2050-01-31T00:00:00',
#  '2075-01-31T00:00:00',
#  '1978-01-0T00:00:00',
#  '1973-01-0T00:00:00',
#  '1972-01-0T00:00:00',
#  '1977-01-0T00:00:00',
#  '1975-01-0T00:00:00',
#  '1976-01-0T00:00:00',
#  '1974-01-0T00:00:00',
#  '2005-12-0T00:00:00',
#  '1979-01-0T00:00:00',
#  '1971-01-0T00:00:00',
#  '2099-10-3T00:00:00',
#  '2099-10-31T00:00:00',
#  '2099-11-31T00:00:00',
#  '2005-11-3T00:00:00',
#  '2005-11-31T00:00:00',
#  '2012-12-31T00:00:00',
#  '2097-12-31T00:00:00',
#  '2084-12-31T00:00:00',
#  '2034-12-31T00:00:00',
#  '2046-12-31T00:00:00',
#  '2035-12-31T00:00:00',
#  '2033-12-31T00:00:00',
#  '2043-12-31T00:00:00',
#  '2099-12-31T00:00:00',
#  '2088-12-31T00:00:00',
#  '2072-12-31T00:00:00',
#  '2025-12-31T00:00:00',
#  '2092-12-31T00:00:00',
#  '2058-12-31T00:00:00',
#  '2076-12-31T00:00:00',
#  '2044-12-31T00:00:00',
#  '2066-12-31T00:00:00',
#  '2063-12-31T00:00:00',
#  '2082-12-31T00:00:00',
#  '2017-12-31T00:00:00',
#  '2049-12-31T00:00:00',
#  '2078-12-31T00:00:00',
#  '2064-12-31T00:00:00',
#  '2042-12-31T00:00:00',
#  '2056-12-31T00:00:00',
#  '2039-12-31T00:00:00',
#  '2029-12-31T00:00:00',
#  '2057-12-31T00:00:00',
#  '2053-12-31T00:00:00',
#  '2023-12-31T00:00:00',
#  '2041-12-31T00:00:00',
#  '2045-12-31T00:00:00',
#  '2089-12-31T00:00:00',
#  '2013-12-31T00:00:00',
#  '2083-12-31T00:00:00',
#  '2048-12-31T00:00:00',
#  '2067-12-31T00:00:00',
#  '2054-12-31T00:00:00',
#  '2085-12-31T00:00:00',
#  '2086-12-31T00:00:00',
#  '2095-12-31T00:00:00',
#  '2062-12-31T00:00:00',
#  '2022-12-31T00:00:00',
#  '2075-12-31T00:00:00',
#  '2052-12-31T00:00:00',
#  '2098-12-31T00:00:00',
#  '2021-12-31T00:00:00',
#  '2014-12-31T00:00:00',
#  '2093-12-31T00:00:00',
#  '2055-12-31T00:00:00',
#  '2047-12-31T00:00:00',
#  '2065-12-31T00:00:00',
#  '2051-12-31T00:00:00',
#  '2032-12-31T00:00:00',
#  '2028-12-31T00:00:00',
#  '2037-12-31T00:00:00',
#  '2079-12-31T00:00:00',
#  '2071-12-31T00:00:00',
#  '2036-12-31T00:00:00',
#  '2031-12-31T00:00:00',
#  '2094-12-31T00:00:00',
#  '2096-12-31T00:00:00',
#  '2081-12-31T00:00:00',
#  '2091-12-31T00:00:00',
#  '2073-12-31T00:00:00',
#  '2059-12-31T00:00:00',
#  '2016-12-31T00:00:00',
#  '2087-12-31T00:00:00',
#  '2068-12-31T00:00:00',
#  '2061-12-31T00:00:00',
#  '2019-12-31T00:00:00',
#  '2038-12-31T00:00:00',
#  '2077-12-31T00:00:00',
#  '2015-12-31T00:00:00',
#  '2074-12-31T00:00:00',
#  '2024-12-31T00:00:00',
#  '2069-12-31T00:00:00',
#  '2027-12-31T00:00:00',
#  '2018-12-31T00:00:00',
#  '2026-12-31T00:00:00',
#  '1952-12-31T00:00:00',
#  '1961-12-31T00:00:00',
#  '1959-12-31T00:00:00',
#  '1969-12-31T00:00:00',
#  '1962-12-31T00:00:00',
#  '1975-12-31T00:00:00',
#  '1951-12-31T00:00:00',
#  '1977-12-31T00:00:00',
#  '1978-12-31T00:00:00',
#  '1957-12-31T00:00:00',
#  '1966-12-31T00:00:00',
#  '1955-12-31T00:00:00',
#  '1964-12-31T00:00:00',
#  '1954-12-31T00:00:00',
#  '1972-12-31T00:00:00',
#  '1968-12-31T00:00:00',
#  '1963-12-31T00:00:00',
#  '1976-12-31T00:00:00',
#  '1965-12-31T00:00:00',
#  '1958-12-31T00:00:00',
#  '1956-12-31T00:00:00',
#  '1967-12-31T00:00:00',
#  '1953-12-31T00:00:00',
#  '1974-12-31T00:00:00',
#  '1973-12-31T00:00:00',
#  '1971-12-31T00:00:00',
#  '2009-11-3T00:00:00',
#  '2100-04-3T00:00:00',
#  '2100-11-3T00:00:00',
#  '2099-11-2T00:00:00',
#  '2011-11-3T00:00:00',
#  '2100-11-31T00:00:00',
#  '2016-11-3T00:00:00',
#  '2016-11-31T00:00:00',
#  '2101-12-31T00:00:00',
#  '2099-12-0T00:00:00',
#  '1949-12-31T00:00:00',
#  '2012-12-0T00:00:00',
#  '2099-12-2T00:00:00',
#  '2099-12-1T00:00:00',
#  '2099-09-3T00:00:00',
#  '2100-03-3T00:00:00',
#  '2030-12-1T00:00:00',
#  '2005-10-3T00:00:00',
#  '2080-12-0T00:00:00',
#  '1998-01-3T00:00:00',
#  '1985-11-3T00:00:00',
#  '2010-11-3T00:00:00']

# %% [markdown]
# ## Write new catalog

# %%
from datetime import datetime

last_updated = datetime.now().utcnow()
version = last_updated.strftime('v%Y%m%d')
cat_name = f"c3s-cica-atlas-v02_{version}.csv.gz"
cat_path = f"../intake/catalogs/c3s-atlas/{cat_name}"

df_new.to_csv(cat_path, index=False, compression="gzip")
# Out:
# /var/folders/5f/t661zdnd181ck1dv429s4p8r0000gn/T/ipykernel_11795/4210049378.py:3: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   last_updated = datetime.now().utcnow()
