# %% [markdown]
# # CMIP6 Decadal catalog

# %%
import intake
import pandas as pd

# %%
cat_url = "https://raw.githubusercontent.com/cp4cds/c3s_34g_manifests/master/intake/catalogs/c3s.yaml"

cat = intake.open_catalog(cat_url)
list(cat)
# Out:
# ['c3s-cmip5',
#  'c3s-cmip5-daily-pressure-level',
#  'c3s-cmip5-daily-single-level',
#  'c3s-cmip5-monthly-pressure-level',
#  'c3s-cmip5-monthly-single-level',
#  'c3s-cmip6',
#  'c3s-cmip6-decadal',
#  'c3s-cmip6-decadal-dwd',
#  'c3s-cordex']

# %% [markdown]
# ## Load combined cmip6 decadal catalog

# %%
df_cmip6_decadal = cat['c3s-cmip6-decadal'].read()
df_cmip6_decadal
# Out:
#                                                     ds_id  \
# 0       c3s-cmip6.DCPP.MPI-M.MPI-ESM1-2-HR.dcppA-hindc...
# 1       c3s-cmip6.DCPP.MPI-M.MPI-ESM1-2-HR.dcppA-hindc...
# 2       c3s-cmip6.DCPP.MOHC.HadGEM3-GC31-MM.dcppA-hind...
# 3       c3s-cmip6.DCPP.MOHC.HadGEM3-GC31-MM.dcppA-hind...
# 4       c3s-cmip6.DCPP.MOHC.HadGEM3-GC31-MM.dcppA-hind...
# ...                                                   ...
# 102225  c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
# 102226  c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
# 102227  c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
# 102228  c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
# 102229  c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
#
#                                                      path       size  \
# 0       DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2016-...  492479692
# 1       DCPP/MPI-M/MPI-ESM1-2-HR/dcppA-hindcast/s2009-...  737204109
# 2       DCPP/MOHC/HadGEM3-GC31-MM/dcppA-hindcast/s1987...     953384
# 3       DCPP/MOHC/HadGEM3-GC31-MM/dcppA-hindcast/s1995...     603757
# 4       DCPP/MOHC/HadGEM3-GC31-MM/dcppA-hindcast/s2004...   14824913
# ...                                                   ...        ...
# 102225  DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s1995-r1...    4119531
# 102226  DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s1973-r1...    6635233
# 102227  DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s2014-r8...    4114536
# 102228  DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s2006-r1...    6641928
# 102229  DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s2012-r1...  138029115
#
#           mip_era activity_id institution_id        source_id   experiment_id  \
# 0       c3s-cmip6        DCPP          MPI-M    MPI-ESM1-2-HR  dcppA-hindcast
# 1       c3s-cmip6        DCPP          MPI-M    MPI-ESM1-2-HR  dcppA-hindcast
# 2       c3s-cmip6        DCPP           MOHC  HadGEM3-GC31-MM  dcppA-hindcast
# 3       c3s-cmip6        DCPP           MOHC  HadGEM3-GC31-MM  dcppA-hindcast
# 4       c3s-cmip6        DCPP           MOHC  HadGEM3-GC31-MM  dcppA-hindcast
# ...           ...         ...            ...              ...             ...
# 102225  c3s-cmip6        DCPP            DWD    MPI-ESM1-2-LR  dcppA-hindcast
# 102226  c3s-cmip6        DCPP            DWD    MPI-ESM1-2-LR  dcppA-hindcast
# 102227  c3s-cmip6        DCPP            DWD    MPI-ESM1-2-LR  dcppA-hindcast
# 102228  c3s-cmip6        DCPP            DWD    MPI-ESM1-2-LR  dcppA-hindcast
# 102229  c3s-cmip6        DCPP            DWD    MPI-ESM1-2-LR  dcppA-hindcast
#
#               member_id table_id variable_id grid_label    version  \
# 0        s2016-r8i1p1f1      day      tasmax         gn  v20210111
# 1        s2009-r8i1p1f1      day          pr         gn  v20210107
# 2        s1987-r3i1p1f2     Amon          pr         gn  v20200417
# 3        s1995-r6i1p1f2     Amon         tas         gn  v20200417
# 4       s2004-r10i1p1f2   AERday       zg500         gn  v20200417
# ...                 ...      ...         ...        ...        ...
# 102225  s1995-r16i1p1f1     Amon         tas         gn  v20220126
# 102226  s1973-r16i1p1f1     Amon          pr         gn  v20220126
# 102227   s2014-r8i1p1f1     Amon         tas         gn  v20220126
# 102228  s2006-r14i1p1f1     Amon          pr         gn  v20220126
# 102229  s2012-r10i1p1f1      day      tasmax         gn  v20220126
#
#                  start_time             end_time                         bbox  \
# 0       2016-11-01T12:00:00  2026-12-31T12:00:00  0.00, -89.28, 359.06, 89.28
# 1       2009-11-01T12:00:00  2019-12-31T12:00:00  0.00, -89.28, 359.06, 89.28
# 2       1987-11-16T00:00:00  1987-12-16T00:00:00  0.42, -89.72, 359.58, 89.72
# 3       1995-11-16T00:00:00  1995-12-16T00:00:00  0.42, -89.72, 359.58, 89.72
# 4       2004-11-01T12:00:00  2004-12-30T12:00:00  0.42, -89.72, 359.58, 89.72
# ...                     ...                  ...                          ...
# 102225  1995-11-30T18:00:00  2005-12-31T18:00:00  0.00, -88.57, 358.12, 88.57
# 102226  1973-11-30T18:00:00  1983-12-31T18:00:00  0.00, -88.57, 358.12, 88.57
# 102227  2014-11-30T18:00:00  2024-12-31T18:00:00  0.00, -88.57, 358.12, 88.57
# 102228  2006-11-30T18:00:00  2016-12-31T18:00:00  0.00, -88.57, 358.12, 88.57
# 102229  2012-11-01T09:00:00  2022-12-31T09:00:00  0.00, -88.57, 358.12, 88.57
#
#            level
# 0           2.00
# 1            NaN
# 2            NaN
# 3           1.50
# 4       50000.00
# ...          ...
# 102225      2.00
# 102226       NaN
# 102227      2.00
# 102228       NaN
# 102229      2.00
#
# [102230 rows x 17 columns]

# %%
df_cmip6_decadal.nunique()
# Out:
# ds_id              18920
# path              102230
# size               95199
# mip_era                1
# activity_id            1
# institution_id         5
# source_id              5
# experiment_id          2
# member_id           1725
# table_id               3
# variable_id            6
# grid_label             2
# version               39
# start_time           538
# end_time             671
# bbox                   6
# level                  3
# dtype: int64

# %%
df_cmip6_decadal.institution_id.unique()
# Out:
# array(['MPI-M', 'MOHC', 'EC-Earth-Consortium', 'CMCC', 'DWD'],
#       dtype=object)

# %%
df_dwd = df_cmip6_decadal.loc[df_cmip6_decadal.institution_id == 'DWD']
df_dwd.nunique()
# Out:
# ds_id             4960
# path              4960
# size              4776
# mip_era              1
# activity_id          1
# institution_id       1
# source_id            1
# experiment_id        1
# member_id          992
# table_id             2
# variable_id          5
# grid_label           1
# version              1
# start_time         124
# end_time           124
# bbox                 1
# level                1
# dtype: int64

# %% [markdown]
# ## Load cmip6 decadal DWD catalog

# %%
df_cmip6_decadal_dwd = cat['c3s-cmip6-decadal-dwd'].read()
df_cmip6_decadal_dwd
# Out:
#                                                   ds_id  \
# 0     c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
# 1     c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
# 2     c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
# 3     c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
# 4     c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
# ...                                                 ...
# 4955  c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
# 4956  c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
# 4957  c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
# 4958  c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
# 4959  c3s-cmip6.DCPP.DWD.MPI-ESM1-2-LR.dcppA-hindcas...
#
#                                                    path       size    mip_era  \
# 0     DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s1984-r1...  139578640  c3s-cmip6
# 1     DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s1993-r8...  139520726  c3s-cmip6
# 2     DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s1968-r1...    6633381  c3s-cmip6
# 3     DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s1979-r3...  138245285  c3s-cmip6
# 4     DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s1972-r1...    6642887  c3s-cmip6
# ...                                                 ...        ...        ...
# 4955  DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s1995-r1...    4119531  c3s-cmip6
# 4956  DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s1973-r1...    6635233  c3s-cmip6
# 4957  DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s2014-r8...    4114536  c3s-cmip6
# 4958  DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s2006-r1...    6641928  c3s-cmip6
# 4959  DCPP/DWD/MPI-ESM1-2-LR/dcppA-hindcast/s2012-r1...  138029115  c3s-cmip6
#
#      activity_id institution_id      source_id   experiment_id  \
# 0           DCPP            DWD  MPI-ESM1-2-LR  dcppA-hindcast
# 1           DCPP            DWD  MPI-ESM1-2-LR  dcppA-hindcast
# 2           DCPP            DWD  MPI-ESM1-2-LR  dcppA-hindcast
# 3           DCPP            DWD  MPI-ESM1-2-LR  dcppA-hindcast
# 4           DCPP            DWD  MPI-ESM1-2-LR  dcppA-hindcast
# ...          ...            ...            ...             ...
# 4955        DCPP            DWD  MPI-ESM1-2-LR  dcppA-hindcast
# 4956        DCPP            DWD  MPI-ESM1-2-LR  dcppA-hindcast
# 4957        DCPP            DWD  MPI-ESM1-2-LR  dcppA-hindcast
# 4958        DCPP            DWD  MPI-ESM1-2-LR  dcppA-hindcast
# 4959        DCPP            DWD  MPI-ESM1-2-LR  dcppA-hindcast
#
#             member_id table_id variable_id grid_label    version  \
# 0     s1984-r10i1p1f1      day      tasmin         gn  v20220126
# 1      s1993-r8i1p1f1      day      tasmin         gn  v20220126
# 2     s1968-r14i1p1f1     Amon          pr         gn  v20220126
# 3      s1979-r3i1p1f1      day      tasmax         gn  v20220126
# 4     s1972-r14i1p1f1     Amon          pr         gn  v20220126
# ...               ...      ...         ...        ...        ...
# 4955  s1995-r16i1p1f1     Amon         tas         gn  v20220126
# 4956  s1973-r16i1p1f1     Amon          pr         gn  v20220126
# 4957   s2014-r8i1p1f1     Amon         tas         gn  v20220126
# 4958  s2006-r14i1p1f1     Amon          pr         gn  v20220126
# 4959  s2012-r10i1p1f1      day      tasmax         gn  v20220126
#
#                start_time             end_time                         bbox  \
# 0     1984-11-01T09:00:00  1994-12-31T09:00:00  0.00, -88.57, 358.12, 88.57
# 1     1993-11-01T09:00:00  2003-12-31T09:00:00  0.00, -88.57, 358.12, 88.57
# 2     1968-11-30T18:00:00  1978-12-31T18:00:00  0.00, -88.57, 358.12, 88.57
# 3     1979-11-01T09:00:00  1989-12-31T09:00:00  0.00, -88.57, 358.12, 88.57
# 4     1972-11-30T18:00:00  1982-12-31T18:00:00  0.00, -88.57, 358.12, 88.57
# ...                   ...                  ...                          ...
# 4955  1995-11-30T18:00:00  2005-12-31T18:00:00  0.00, -88.57, 358.12, 88.57
# 4956  1973-11-30T18:00:00  1983-12-31T18:00:00  0.00, -88.57, 358.12, 88.57
# 4957  2014-11-30T18:00:00  2024-12-31T18:00:00  0.00, -88.57, 358.12, 88.57
# 4958  2006-11-30T18:00:00  2016-12-31T18:00:00  0.00, -88.57, 358.12, 88.57
# 4959  2012-11-01T09:00:00  2022-12-31T09:00:00  0.00, -88.57, 358.12, 88.57
#
#      level
# 0     2.00
# 1     2.00
# 2      NaN
# 3     2.00
# 4      NaN
# ...    ...
# 4955  2.00
# 4956   NaN
# 4957  2.00
# 4958   NaN
# 4959  2.00
#
# [4960 rows x 17 columns]

# %%
df_cmip6_decadal_dwd.nunique()
# Out:
# ds_id             4960
# path              4960
# size              4776
# mip_era              1
# activity_id          1
# institution_id       1
# source_id            1
# experiment_id        1
# member_id          992
# table_id             2
# variable_id          5
# grid_label           1
# version              1
# start_time         124
# end_time           124
# bbox                 1
# level                1
# dtype: int64
